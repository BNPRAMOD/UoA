# %% [markdown]
# # **Layer 1: Baseline DeiT environment**

# %% [markdown]
# DeiT’s baseline training script expects a teacher model name and distillation settings via CLI flags in main.py (e.g., --teacher-model, --teacher-path, --distillation-type).
# GitHub
# +1
#
# So the “base environment” Layer 1 must include:
#
# DeiT repo (cloned)
#
# PyTorch (Colab default) + GPU
#
# timm installed (for both student and teacher models)
#
# compatibility patches if any (because Colab uses new torch/timm)

# %% [markdown]
# Install PyTorch without pinning

# %%
# !pip -q install --upgrade pip
# !pip -q install torch torchvision torchaudio

# %% [markdown]
# Verify

# %%
import torch
print(torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# 2.9.0+cu128
# CUDA: True

# %% [markdown]
# Clone the baseline repo (official DeiT)

# %%
# %cd /content
# !git clone https://github.com/facebookresearch/deit.git
# %cd /content/deit
# !grep -n "torch" -n requirements.txt || true
# Out:
# /content
# fatal: destination path 'deit' already exists and is not an empty directory.
# /content/deit

# %% [markdown]
# Colab Compatibility Fixes
#
# 1. torch pin removal
#
# 2. timm API changes
#
# 3. kwargs popping (pretrained_cfg, cache_dir, etc.)

# %% [markdown]
# Patch requirements.txt to remove torch pins

# %%
# %cd /content/deit

# !python - << 'PY'
from pathlib import Path
p = Path("requirements.txt")
lines = p.read_text().splitlines()

filtered = []
removed = []
for line in lines:
    s = line.strip()
    if s.startswith("torch==") or s.startswith("torchvision==") or s.startswith("torchaudio=="):
        removed.append(line)
        continue
    filtered.append(line)

p.write_text("\n".join(filtered) + "\n")
print("✅ Removed these pinned lines:")
for r in removed:
    print("  -", r)
# Out:
# /content/deit
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ✅ Removed these pinned lines:

# %% [markdown]
# Verify Pins are gone!i.e torch==1.13.1 pin was removed

# %%
# !grep -nE "torch|torchvision|torchaudio" requirements.txt || echo "✅ No torch pins remain"
# Out:
# ✅ No torch pins remain

# %% [markdown]
# Install the baseline dependencies

# %%
pip install "jedi>=0.16,<0.19"
# Out:
# Requirement already satisfied: jedi<0.19,>=0.16 in /usr/local/lib/python3.12/dist-packages (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from jedi<0.19,>=0.16) (0.8.5)

# %%
# !pip -q uninstall -y timm
# !pip -q install "jedi>=0.16,<0.19"
# !pip -q install timm==0.6.13 submitit

# %%
#!pip -q uninstall -y timm
#!pip -q install -U pip setuptools wheel
#!pip -q install -U "timm>=1.0.0"

# %% [markdown]
# Verify

# %%
# !python -c "import timm; print('timm:', timm.__version__)"
# Out:
# timm: 0.6.13

# %% [markdown]
# **Restart the Session**

# %%
# !python - << 'PY'
from pathlib import Path

p = Path("/usr/local/lib/python3.12/dist-packages/timm/data/__init__.py")
txt = p.read_text()

needle = "OPENAI_CLIP_MEAN"
if needle in txt:
    print("✅ timm.data already mentions OPENAI_CLIP_MEAN; no patch needed.")
else:
    patch = """

# --- Colab patch: expose CLIP normalization constants for older exports ---
try:
    from .constants import OPENAI_CLIP_MEAN, OPENAI_CLIP_STD  # timm versions where defined in constants
except Exception:
    # Standard OpenAI CLIP normalization
    OPENAI_CLIP_MEAN = (0.48145466, 0.4578275, 0.40821073)
    OPENAI_CLIP_STD  = (0.26862954, 0.26130258, 0.27577711)
# --- end patch ---
"""
    p.write_text(txt + patch)
    print("✅ Patched:", p)
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ✅ Patched: /usr/local/lib/python3.12/dist-packages/timm/data/__init__.py

# %% [markdown]
# Runtime → Restart runtime

# %%
#!pip -q install timm submitit

# %%
# %cd /content/deit
from models import deit_tiny_patch16_224
m = deit_tiny_patch16_224()
print("✅ DeiT model instantiated successfully")
# Out:
# /content/deit
# ✅ DeiT model instantiated successfully

# %%
import torch, timm
print(torch.__version__)
print(timm.__version__)
print(torch.cuda.is_available())
# Out:
# 2.9.0+cu128
# 0.6.13
# True

# %% [markdown]
# Download Tiny-ImageNet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !wget -q http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip
# Out:
# /content
# replace tiny-imagenet-200/words.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# Fix Tiny-ImageNet validation folder

# %%
# !python - << 'EOF'
import shutil
from pathlib import Path

root = Path("/content/tiny-imagenet-200")
val_dir = root/"val"
img_dir = val_dir/"images"
ann = val_dir/"val_annotations.txt"

with ann.open("r") as f:
    for line in f:
        img, cls = line.strip().split("\t")[:2]
        (val_dir/cls).mkdir(parents=True, exist_ok=True)
        src = img_dir/img
        dst = val_dir/cls/img
        if src.exists():
            shutil.move(str(src), str(dst))

if img_dir.exists():
    shutil.rmtree(img_dir)

print("✅ Tiny-ImageNet val reorganized into class subfolders.")
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `EOF')
# ✅ Tiny-ImageNet val reorganized into class subfolders.

# %%
# !find /content/tiny-imagenet-200/val -maxdepth 1 -type d | head
# Out:
# /content/tiny-imagenet-200/val
# /content/tiny-imagenet-200/val/n02002724
# /content/tiny-imagenet-200/val/n03447447
# /content/tiny-imagenet-200/val/n07715103
# /content/tiny-imagenet-200/val/n02486410
# /content/tiny-imagenet-200/val/n01770393
# /content/tiny-imagenet-200/val/n02666196
# /content/tiny-imagenet-200/val/n02892201
# /content/tiny-imagenet-200/val/n04356056
# /content/tiny-imagenet-200/val/n02364673

# %%
ls -lah /content/tiny-imagenet-200 | head
# Out:
# total 2.6M
# drwxrwxr-x   5 root root 4.0K Feb 13 11:07 ./
# drwxr-xr-x   1 root root 4.0K Feb 13 10:52 ../
# drwxrwxr-x   3 root root 4.0K Dec 12  2014 test/
# drwxrwxr-x 202 root root 4.0K Dec 12  2014 train/
# drwxrwxr-x 202 root root 4.0K Feb 13 11:07 val/
# -rw-rw-r--   1 root root 2.0K Feb  9  2015 wnids.txt
# -rw-------   1 root root 2.6M Feb  9  2015 words.txt

# %% [markdown]
# Handle timm incompatibilities. Although we can instantiate the model directly, the training script uses timm.create_model(), which injects metadata arguments such as pretrained_cfg and cache_dir.
# The original DeiT constructors do not support these arguments, so we remove them
# YOUR NOTEBOOK CALL
#     |
#     v
# deit_tiny_patch16_224()          ✅ works (no kwargs)
#
# TRAINING PIPELINE
#     |
#     v
# timm.create_model()
#     |
#     v
# deit_tiny_patch16_224(**kwargs)  ❌ injects extra keys

# %% [markdown]
# Patch /content/deit/augment.py (safe compatibility fix)

# %%
# %cd /content/deit
# !python - << 'PY'
from pathlib import Path
p = Path("augment.py")
txt = p.read_text()

old = "from timm.data.transforms import _pil_interp, RandomResizedCropAndInterpolation, ToNumpy, ToTensor"
if old in txt:
    txt = txt.replace(
        old,
        "from timm.data.transforms import RandomResizedCropAndInterpolation, ToNumpy, ToTensor\n"
        "try:\n"
        "    from timm.data.transforms import _pil_interp  # older timm\n"
        "except Exception:\n"
        "    _pil_interp = None  # newer timm doesn't expose this\n"
    )
    p.write_text(txt)
    print("✅ Patched augment.py for timm compatibility.")
else:
    print("ℹ️ Expected import line not found; augment.py may already be patched or different.")
# Out:
# /content/deit
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ℹ️ Expected import line not found; augment.py may already be patched or different.

# %%
# %cd /content/deit
# !sed -n '1,200p' models.py
# Out:
# /content/deit
# # Copyright (c) 2015-present, Facebook, Inc.
# # All rights reserved.
# import torch
# import torch.nn as nn
# from functools import partial
#
# from timm.models.vision_transformer import VisionTransformer, _cfg
# from timm.models.registry import register_model
# from timm.models.layers import trunc_normal_
#
#
# __all__ = [
#     'deit_tiny_patch16_224', 'deit_small_patch16_224', 'deit_base_patch16_224',
#     'deit_tiny_distilled_patch16_224', 'deit_small_distilled_patch16_224',
#     'deit_base_distilled_patch16_224', 'deit_base_patch16_384',
#     'deit_base_distilled_patch16_384',
# ]
#
#
# class DistilledVisionTransformer(VisionTransformer):
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#         self.dist_token = nn.Parameter(torch.zeros(1, 1, self.embed_dim))
#         num_patches = self.patch_embed.num_patches
#         self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 2, self.embed_dim))
#         self.head_dist = nn.Linear(self.embed_dim, self.num_classes) if self.num_classes > 0 else nn.Identity()
#
#         trunc_normal_(self.dist_token, std=.02)
#         trunc_normal_(self.pos_embed, std=.02)
#         self.head_dist.apply(self._init_weights)
#
#     def forward_features(self, x):
#         # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#         # with slight modifications to add the dist_token
#         B = x.shape[0]
#         x = self.patch_embed(x)
#
#         cls_tokens = self.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
#         dist_token = self.dist_token.expand(B, -1, -1)
#         x = torch.cat((cls_tokens, dist_token, x), dim=1)
#
#         x = x + self.pos_embed
#         x = self.pos_drop(x)
#
#         for blk in self.blocks:
#             x = blk(x)
#
#         x = self.norm(x)
#         return x[:, 0], x[:, 1]
#
#     def forward(self, x):
#         x, x_dist = self.forward_features(x)
#         x = self.head(x)
#         x_dist = self.head_dist(x_dist)
#         if self.training:
#             return x, x_dist
#         else:
#             # during inference, return the average of both classifier predictions
#             return (x + x_dist) / 2
#
#
# @register_model
# def deit_tiny_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=192, depth=12, num_heads=3, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_small_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=384, depth=12, num_heads=6, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_small_patch16_224-cd65a155.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_base_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=768, depth=12, num_heads=12, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_base_patch16_224-b5f2ef4d.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_tiny_distilled_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = DistilledVisionTransformer(
#         patch_size=16, embed_dim=192, depth=12, num_heads=3, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_tiny_distilled_patch16_224-b40b3cf7.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model

# %% [markdown]
# Before constructing the model, remove those keys from kwargs

# %%
from pathlib import Path

p = Path("/content/deit/models.py")
lines = p.read_text().splitlines()

out = []
for line in lines:
    out.append(line)
    if line.strip().startswith("def deit_") and "**kwargs" in line:
        out.append("    # Drop timm-injected kwargs not supported by DeiT")
        out.append("    kwargs.pop('pretrained_cfg', None)")
        out.append("    kwargs.pop('pretrained_cfg_overlay', None)")
        out.append("    kwargs.pop('pretrained_cfg_priority', None)")

p.write_text("\n".join(out) + "\n")
print("✅ models.py patched to drop pretrained_cfg kwargs")
# Out:
# ✅ models.py patched to drop pretrained_cfg kwargs

# %% [markdown]
# Verify

# %%
# !grep -n "pretrained_cfg" /content/deit/models.py
# Out:
# 65:    kwargs.pop('pretrained_cfg', None)
# 66:    kwargs.pop('pretrained_cfg_overlay', None)
# 67:    kwargs.pop('pretrained_cfg_priority', None)
# 73:    kwargs.pop('pretrained_cfg', None)
# 74:    kwargs.pop('pretrained_cfg_overlay', None)
# 75:    kwargs.pop('pretrained_cfg_priority', None)
# 85:    kwargs.pop('pretrained_cfg', None)
# 86:    kwargs.pop('pretrained_cfg_overlay', None)
# 87:    kwargs.pop('pretrained_cfg_priority', None)
# 104:    kwargs.pop('pretrained_cfg', None)
# 105:    kwargs.pop('pretrained_cfg_overlay', None)
# 106:    kwargs.pop('pretrained_cfg_priority', None)
# 112:    kwargs.pop('pretrained_cfg', None)
# 113:    kwargs.pop('pretrained_cfg_overlay', None)
# 114:    kwargs.pop('pretrained_cfg_priority', None)
# 124:    kwargs.pop('pretrained_cfg', None)
# 125:    kwargs.pop('pretrained_cfg_overlay', None)
# 126:    kwargs.pop('pretrained_cfg_priority', None)
# 143:    kwargs.pop('pretrained_cfg', None)
# 144:    kwargs.pop('pretrained_cfg_overlay', None)
# 145:    kwargs.pop('pretrained_cfg_priority', None)
# 151:    kwargs.pop('pretrained_cfg', None)
# 152:    kwargs.pop('pretrained_cfg_overlay', None)
# 153:    kwargs.pop('pretrained_cfg_priority', None)
# 163:    kwargs.pop('pretrained_cfg', None)
# 164:    kwargs.pop('pretrained_cfg_overlay', None)
# 165:    kwargs.pop('pretrained_cfg_priority', None)
# 182:    kwargs.pop('pretrained_cfg', None)
# 183:    kwargs.pop('pretrained_cfg_overlay', None)
# 184:    kwargs.pop('pretrained_cfg_priority', None)
# 190:    kwargs.pop('pretrained_cfg', None)
# 191:    kwargs.pop('pretrained_cfg_overlay', None)
# 192:    kwargs.pop('pretrained_cfg_priority', None)
# 202:    kwargs.pop('pretrained_cfg', None)
# 203:    kwargs.pop('pretrained_cfg_overlay', None)
# 204:    kwargs.pop('pretrained_cfg_priority', None)
# 221:    kwargs.pop('pretrained_cfg', None)
# 222:    kwargs.pop('pretrained_cfg_overlay', None)
# 223:    kwargs.pop('pretrained_cfg_priority', None)
# 229:    kwargs.pop('pretrained_cfg', None)
# 230:    kwargs.pop('pretrained_cfg_overlay', None)
# 231:    kwargs.pop('pretrained_cfg_priority', None)
# 241:    kwargs.pop('pretrained_cfg', None)
# 242:    kwargs.pop('pretrained_cfg_overlay', None)
# 243:    kwargs.pop('pretrained_cfg_priority', None)
# 260:    kwargs.pop('pretrained_cfg', None)
# 261:    kwargs.pop('pretrained_cfg_overlay', None)
# 262:    kwargs.pop('pretrained_cfg_priority', None)
# 268:    kwargs.pop('pretrained_cfg', None)
# 269:    kwargs.pop('pretrained_cfg_overlay', None)
# 270:    kwargs.pop('pretrained_cfg_priority', None)
# 280:    kwargs.pop('pretrained_cfg', None)
# 281:    kwargs.pop('pretrained_cfg_overlay', None)
# 282:    kwargs.pop('pretrained_cfg_priority', None)
# 299:    kwargs.pop('pretrained_cfg', None)
# 300:    kwargs.pop('pretrained_cfg_overlay', None)
# 301:    kwargs.pop('pretrained_cfg_priority', None)
# 307:    kwargs.pop('pretrained_cfg', None)
# 308:    kwargs.pop('pretrained_cfg_overlay', None)
# 309:    kwargs.pop('pretrained_cfg_priority', None)
# 319:    kwargs.pop('pretrained_cfg', None)
# 320:    kwargs.pop('pretrained_cfg_overlay', None)
# 321:    kwargs.pop('pretrained_cfg_priority', None)
# 338:    kwargs.pop('pretrained_cfg', None)
# 339:    kwargs.pop('pretrained_cfg_overlay', None)
# 340:    kwargs.pop('pretrained_cfg_priority', None)
# 346:    kwargs.pop('pretrained_cfg', None)
# 347:    kwargs.pop('pretrained_cfg_overlay', None)
# 348:    kwargs.pop('pretrained_cfg_priority', None)
# 358:    kwargs.pop('pretrained_cfg', None)
# 359:    kwargs.pop('pretrained_cfg_overlay', None)
# 360:    kwargs.pop('pretrained_cfg_priority', None)

# %% [markdown]
# Fix: Patch /content/deit/models.py to drop pretrained_cfg=...

# %% [markdown]
# Patch models.py to also drop cache_dir (and friends)

# %%
from pathlib import Path

p = Path("/content/deit/models.py")
lines = p.read_text().splitlines()

# Keys that timm may inject but DeiT constructors don't accept
DROP_KEYS = [
    "cache_dir",
    "hf_hub_id",
    "hf_hub_filename",
    "hf_hub_revision",
]

out = []
for line in lines:
    out.append(line)
    # Right after the comment line we previously inserted, add more pops once per function
    if line.strip() == "# Drop timm-injected kwargs not supported by DeiT":
        for k in DROP_KEYS:
            out.append(f"    kwargs.pop('{k}', None)")

p.write_text("\n".join(out) + "\n")
print("✅ Patched models.py to drop cache_dir/hf_hub* kwargs")
# Out:
# ✅ Patched models.py to drop cache_dir/hf_hub* kwargs

# %% [markdown]
# Verify

# %%
# !grep -n "cache_dir" /content/deit/models.py
# Out:
# 65:    kwargs.pop('cache_dir', None)
# 73:    kwargs.pop('cache_dir', None)
# 77:    kwargs.pop('cache_dir', None)
# 85:    kwargs.pop('cache_dir', None)
# 89:    kwargs.pop('cache_dir', None)
# 93:    kwargs.pop('cache_dir', None)
# 116:    kwargs.pop('cache_dir', None)
# 124:    kwargs.pop('cache_dir', None)
# 128:    kwargs.pop('cache_dir', None)
# 136:    kwargs.pop('cache_dir', None)
# 140:    kwargs.pop('cache_dir', None)
# 144:    kwargs.pop('cache_dir', None)
# 167:    kwargs.pop('cache_dir', None)
# 175:    kwargs.pop('cache_dir', None)
# 179:    kwargs.pop('cache_dir', None)
# 187:    kwargs.pop('cache_dir', None)
# 191:    kwargs.pop('cache_dir', None)
# 195:    kwargs.pop('cache_dir', None)
# 218:    kwargs.pop('cache_dir', None)
# 226:    kwargs.pop('cache_dir', None)
# 230:    kwargs.pop('cache_dir', None)
# 238:    kwargs.pop('cache_dir', None)
# 242:    kwargs.pop('cache_dir', None)
# 246:    kwargs.pop('cache_dir', None)
# 269:    kwargs.pop('cache_dir', None)
# 277:    kwargs.pop('cache_dir', None)
# 281:    kwargs.pop('cache_dir', None)
# 289:    kwargs.pop('cache_dir', None)
# 293:    kwargs.pop('cache_dir', None)
# 297:    kwargs.pop('cache_dir', None)
# 320:    kwargs.pop('cache_dir', None)
# 328:    kwargs.pop('cache_dir', None)
# 332:    kwargs.pop('cache_dir', None)
# 340:    kwargs.pop('cache_dir', None)
# 344:    kwargs.pop('cache_dir', None)
# 348:    kwargs.pop('cache_dir', None)
# 371:    kwargs.pop('cache_dir', None)
# 379:    kwargs.pop('cache_dir', None)
# 383:    kwargs.pop('cache_dir', None)
# 391:    kwargs.pop('cache_dir', None)
# 395:    kwargs.pop('cache_dir', None)
# 399:    kwargs.pop('cache_dir', None)
# 422:    kwargs.pop('cache_dir', None)
# 430:    kwargs.pop('cache_dir', None)
# 434:    kwargs.pop('cache_dir', None)
# 442:    kwargs.pop('cache_dir', None)
# 446:    kwargs.pop('cache_dir', None)
# 450:    kwargs.pop('cache_dir', None)

# %%
# %cd /content/deit
# !python main.py \
#   --model deit_tiny_patch16_224 \
#   --data-path /content/tiny-imagenet-200 \
#   --pretrained \
#   --epochs 1 \
#   --batch-size 64 \
#   --num_workers 2 \
#   --output_dir /content/deit_runs/smoke_test
# %cd /content/deit
# !python main.py \
#   --model deit_tiny_patch16_224 \
#   --data-path /content/tiny-imagenet-200 \
#   --epochs 1 \
#   --batch-size 128 \
#   --num_workers 4 \
#   --input-size 224 \
#   --opt adamw \
#   --lr 5e-4 \
#   --weight-decay 0.05 \
#   --sched cosine \
#   --aa rand-m9-mstd0.5 \
#   --reprob 0.25 \
#   --remode pixel \
#   --recount 1 \
#   --output_dir /content/deit_runs/tiny_imagenet
# %cd /content/deit
# !python main.py \
#  --model deit_tiny_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 3e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.1 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.1 \
#  --output_dir /content/deit_runs/tiny_imagenet_5ep
# %cd /content/deit
# !python main.py \
#   --model deit_tiny_distilled_patch16_224 \
#   --data-path /content/tiny-imagenet-200 \
#   --input-size 224 \
#   --epochs 100 \
#   --batch-size 128 \
#   --opt adamw \
#   --lr 0.001 \
#   --sched cosine \
#   --warmup-epochs 5 \
#   --weight-decay 0.05 \
#   --smoothing 0.1 \
#   --drop 0.0 \
#   --drop-path 0.1 \
#   --repeated-aug \
#   --aa rand-m9-mstd0.5-inc1 \
#   --mixup 0.8 \
#   --cutmix 1.0 \
#   --reprob 0.25 \
#   --distillation-type soft \
#   --distillation-alpha 0.1 \
#   --distillation-tau 3.0 \
#   --teacher-model regnety_160 \
#   --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
#   --output_dir /content/deit_runs/paper_recipe
# %cd /content/deit
# !python main.py \
  --model deit_tiny_distilled_patch16_224 \
  --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_distilled_patch16_224-b40b3cf7.pth \
  --data-path /content/tiny-imagenet-200 \
  --input-size 224 \
  --epochs 10 \
  --batch-size 128 \
  --opt adamw \
  --lr 2e-4 \
  --warmup-epochs 2 \
  --weight-decay 0.05 \
  --mixup 0.4 --cutmix 0.5 \
  --distillation-type none \
  --output_dir /content/deit_runs/tinyimg_ft_stageA
# Patch DeiT main.py to fix PyTorch 2.6 resume issue
from pathlib import Path

p = Path("/content/deit/main.py")
txt = p.read_text()

old = "checkpoint = torch.load(args.resume, map_location='cpu')"
new = "checkpoint = torch.load(args.resume, map_location='cpu', weights_only=False)"

if old in txt:
    txt = txt.replace(old, new)
    p.write_text(txt)
    print("✅ Patched main.py to allow resume under PyTorch 2.6")
else:
    print("⚠️ Resume load line not found — may already be patched.")


# %cd /content/deit
# !python main.py \
  --model deit_tiny_distilled_patch16_224 \
  --resume /content/deit_runs/tinyimg_ft_stageA/checkpoint.pth \
  --data-path /content/tiny-imagenet-200 \
  --input-size 224 \
  --epochs 90 \
  --batch-size 128 \
  --opt adamw \
  --lr 2e-4 \
  --warmup-epochs 1 \
  --weight-decay 0.05 \
  --mixup 0.4 --cutmix 0.5 \
  --distillation-type soft \
  --distillation-alpha 0.2 \
  --distillation-tau 3.0 \
  --teacher-model regnety_160 \
  --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
  --output_dir /content/deit_runs/tinyimg_ft_distill_stageB


# Step A (finetune student normally) — fine-tune the pretrained student checkpoint without any teacher flags. Save the resulting checkpoint.

# Step B (resume with distillation) — resume training from that checkpoint and enable the teacher/distillation flags.


# %cd /content/deit
# !python main.py \
#  --model deit_tiny_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 2.5e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.1 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.1 \
#  --distillation-type hard \
# --teacher-model regnety_160 \
# --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
#  --output_dir /content/deit_runs/tiny_imagenet_10ep
# %cd /content/deit
# !python main.py \
#  --model deit_tiny_distilled_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 7e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.0 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.0 \
#  --distillation-type hard \
#  --distillation-alpha 0.7 \
#  --teacher-model regnety_160 \
#  --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
#  --output_dir /content/deit_runs/deit_tiny_distilled_10ep
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [35]  [610/781]  eta: 0:00:22  lr: 0.000010  loss: 2.9295 (2.8765)  time: 0.1397  data: 0.0003  max mem: 6778
# Epoch: [35]  [620/781]  eta: 0:00:21  lr: 0.000010  loss: 3.0322 (2.8769)  time: 0.1388  data: 0.0003  max mem: 6778
# Epoch: [35]  [630/781]  eta: 0:00:19  lr: 0.000010  loss: 2.8606 (2.8758)  time: 0.1262  data: 0.0003  max mem: 6778
# Epoch: [35]  [640/781]  eta: 0:00:18  lr: 0.000010  loss: 2.9236 (2.8805)  time: 0.1260  data: 0.0003  max mem: 6778
# Epoch: [35]  [650/781]  eta: 0:00:17  lr: 0.000010  loss: 2.9236 (2.8792)  time: 0.1270  data: 0.0003  max mem: 6778
# Epoch: [35]  [660/781]  eta: 0:00:15  lr: 0.000010  loss: 2.7111 (2.8767)  time: 0.1277  data: 0.0004  max mem: 6778
# Epoch: [35]  [670/781]  eta: 0:00:14  lr: 0.000010  loss: 2.4729 (2.8713)  time: 0.1309  data: 0.0004  max mem: 6778
# Epoch: [35]  [680/781]  eta: 0:00:13  lr: 0.000010  loss: 2.5804 (2.8712)  time: 0.1333  data: 0.0004  max mem: 6778
# Epoch: [35]  [690/781]  eta: 0:00:12  lr: 0.000010  loss: 2.8129 (2.8702)  time: 0.1295  data: 0.0004  max mem: 6778
# Epoch: [35]  [700/781]  eta: 0:00:10  lr: 0.000010  loss: 2.8723 (2.8700)  time: 0.1277  data: 0.0003  max mem: 6778
# Epoch: [35]  [710/781]  eta: 0:00:09  lr: 0.000010  loss: 3.1477 (2.8714)  time: 0.1277  data: 0.0003  max mem: 6778
# Epoch: [35]  [720/781]  eta: 0:00:08  lr: 0.000010  loss: 3.2385 (2.8744)  time: 0.1271  data: 0.0003  max mem: 6778
# Epoch: [35]  [730/781]  eta: 0:00:06  lr: 0.000010  loss: 3.1101 (2.8741)  time: 0.1276  data: 0.0003  max mem: 6778
# Epoch: [35]  [740/781]  eta: 0:00:05  lr: 0.000010  loss: 2.6146 (2.8708)  time: 0.1278  data: 0.0003  max mem: 6778
# Epoch: [35]  [750/781]  eta: 0:00:04  lr: 0.000010  loss: 2.7220 (2.8708)  time: 0.1282  data: 0.0003  max mem: 6778
# Epoch: [35]  [760/781]  eta: 0:00:02  lr: 0.000010  loss: 2.9961 (2.8734)  time: 0.1296  data: 0.0003  max mem: 6778
# Epoch: [35]  [770/781]  eta: 0:00:01  lr: 0.000010  loss: 3.1690 (2.8736)  time: 0.1285  data: 0.0008  max mem: 6778
# Epoch: [35]  [780/781]  eta: 0:00:00  lr: 0.000010  loss: 2.7252 (2.8721)  time: 0.1254  data: 0.0006  max mem: 6778
# Epoch: [35] Total time: 0:01:42 (0.1316 s / it)
# Averaged stats: lr: 0.000010  loss: 2.7252 (2.8721)
# Test:  [ 0/53]  eta: 0:00:54  loss: 2.3904 (2.3904)  acc1: 72.9167 (72.9167)  acc5: 93.2292 (93.2292)  time: 1.0223  data: 0.9931  max mem: 6778
  [700/781]  eta: 0:00:10  lr: 0.000010  loss: 2.9008 (2.7313)  time: 0.1263  data: 0.0003  max mem: 6778
# Epoch: [89]  [710/781]  eta: 0:00:09  lr: 0.000010  loss: 2.7657 (2.7309)  time: 0.1261  data: 0.0003  max mem: 6778
# Epoch: [89]  [720/781]  eta: 0:00:08  lr: 0.000010  loss: 2.8003 (2.7333)  time: 0.1263  data: 0.0003  max mem: 6778
# Epoch: [89]  [730/781]  eta: 0:00:06  lr: 0.000010  loss: 2.9391 (2.7334)  time: 0.1267  data: 0.0003  max mem: 6778
# Epoch: [89]  [740/781]  eta: 0:00:05  lr: 0.000010  loss: 2.7488 (2.7331)  time: 0.1275  data: 0.0003  max mem: 6778
# Epoch: [89]  [750/781]  eta: 0:00:04  lr: 0.000010  loss: 2.7488 (2.7333)  time: 0.1286  data: 0.0003  max mem: 6778
# Epoch: [89]  [760/781]  eta: 0:00:02  lr: 0.000010  loss: 2.9271 (2.7359)  time: 0.1307  data: 0.0003  max mem: 6778
# Epoch: [89]  [770/781]  eta: 0:00:01  lr: 0.000010  loss: 2.8148 (2.7344)  time: 0.1292  data: 0.0006  max mem: 6778
# Epoch: [89]  [780/781]  eta: 0:00:00  lr: 0.000010  loss: 2.8148 (2.7352)  time: 0.1256  data: 0.0005  max mem: 6778
# Epoch: [89] Total time: 0:01:42 (0.1315 s / it)
# Averaged stats: lr: 0.000010  loss: 2.8148 (2.7352)
# Test:  [ 0/53]  eta: 0:01:20  loss: 2.5726 (2.5726)  acc1: 76.0417 (76.0417)  acc5: 94.2708 (94.2708)  time: 1.5172  data: 1.4845  max mem: 6778
# Test:  [10/53]  eta: 0:00:08  loss: 2.8444 (2.8189)  acc1: 72.9167 (72.4432)  acc5: 93.2292 (92.9924)  time: 0.2005  data: 0.1711  max mem: 6778
# Test:  [20/53]  eta: 0:00:04  loss: 2.9091 (2.8684)  acc1: 71.3542 (73.4871)  acc5: 91.6667 (92.4851)  time: 0.0743  data: 0.0459  max mem: 6778
# Test:  [30/53]  eta: 0:00:02  loss: 3.0215 (2.9148)  acc1: 72.9167 (73.9751)  acc5: 91.1458 (92.0363)  time: 0.0782  data: 0.0501  max mem: 6778
# Test:  [40/53]  eta: 0:00:01  loss: 2.9830 (2.9382)  acc1: 73.4375 (73.4756)  acc5: 91.1458 (91.5142)  time: 0.0685  data: 0.0404  max mem: 6778
# Test:  [50/53]  eta: 0:00:00  loss: 2.8552 (2.9235)  acc1: 75.0000 (74.2136)  acc5: 92.1875 (91.9118)  time: 0.0508  data: 0.0232  max mem: 6778
# Test:  [52/53]  eta: 0:00:00  loss: 2.8620 (2.9340)  acc1: 75.0000 (73.9800)  acc5: 92.7083 (91.9300)  time: 0.0499  data: 0.0231  max mem: 6778
# Test: Total time: 0:00:05 (0.0951 s / it)
# * Acc@1 73.980 Acc@5 91.930 loss 2.934
# Accuracy of the network on the 10000 test images: 74.0%
# Max accuracy: 74.63%
# Training time 2:23:29

# %% [markdown]
# # **Layer 2: Base Environment — Teacher Models & Multi-Teacher Adaptations**

# %% [markdown]
# Layer 2 extends the baseline DeiT environment to support knowledge distillation from one or more teacher models. This layer is additive: it does not modify the baseline DeiT training loop unless explicitly stated.
# It includes
# 1. Teacher Model Support (Single & Multiple)
# 2. Teacher Registry / Configuration
# 3. Multi-Teacher Fusion Mechanism (Adaptation Layer)
# 4. Distillation Loss Integration
