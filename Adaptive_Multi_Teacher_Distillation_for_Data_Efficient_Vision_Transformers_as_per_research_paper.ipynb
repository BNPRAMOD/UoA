# %% [markdown]
# # **Layer 1: Baseline DeiT environment**

# %% [markdown]
# DeiT’s baseline training script expects a teacher model name and distillation settings via CLI flags in main.py (e.g., --teacher-model, --teacher-path, --distillation-type).
# GitHub
# +1
#
# So the “base environment” Layer 1 must include:
#
# DeiT repo (cloned)
#
# PyTorch (Colab default) + GPU
#
# timm installed (for both student and teacher models)
#
# compatibility patches if any (because Colab uses new torch/timm)

# %% [markdown]
# Install PyTorch without pinning

# %%
# !pip -q install --upgrade pip
# !pip -q install torch torchvision torchaudio

# %% [markdown]
# Verify

# %%
import torch
print(torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# 2.9.0+cu128
# CUDA: True

# %% [markdown]
# Clone the baseline repo (official DeiT)

# %%
# %cd /content
# !git clone https://github.com/facebookresearch/deit.git
# %cd /content/deit
# !grep -n "torch" -n requirements.txt || true
# Out:
# /content
# fatal: destination path 'deit' already exists and is not an empty directory.
# /content/deit

# %% [markdown]
# Colab Compatibility Fixes
#
# 1. torch pin removal
#
# 2. timm API changes
#
# 3. kwargs popping (pretrained_cfg, cache_dir, etc.)

# %% [markdown]
# Patch requirements.txt to remove torch pins

# %%
# %cd /content/deit

# !python - << 'PY'
from pathlib import Path
p = Path("requirements.txt")
lines = p.read_text().splitlines()

filtered = []
removed = []
for line in lines:
    s = line.strip()
    if s.startswith("torch==") or s.startswith("torchvision==") or s.startswith("torchaudio=="):
        removed.append(line)
        continue
    filtered.append(line)

p.write_text("\n".join(filtered) + "\n")
print("✅ Removed these pinned lines:")
for r in removed:
    print("  -", r)
# Out:
# /content/deit
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ✅ Removed these pinned lines:

# %% [markdown]
# Verify Pins are gone!i.e torch==1.13.1 pin was removed

# %%
# !grep -nE "torch|torchvision|torchaudio" requirements.txt || echo "✅ No torch pins remain"
# Out:
# ✅ No torch pins remain

# %% [markdown]
# Install the baseline dependencies

# %%
pip install "jedi>=0.16,<0.19"
# Out:
# Requirement already satisfied: jedi<0.19,>=0.16 in /usr/local/lib/python3.12/dist-packages (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from jedi<0.19,>=0.16) (0.8.5)

# %%
# !pip -q uninstall -y timm
# !pip -q install "jedi>=0.16,<0.19"
# !pip -q install timm==0.6.13 submitit

# %%
#!pip -q uninstall -y timm
#!pip -q install -U pip setuptools wheel
#!pip -q install -U "timm>=1.0.0"

# %% [markdown]
# Verify

# %%
# !python -c "import timm; print('timm:', timm.__version__)"
# Out:
# timm: 0.6.13

# %% [markdown]
# **Restart the Session**

# %%
# !python - << 'PY'
from pathlib import Path

p = Path("/usr/local/lib/python3.12/dist-packages/timm/data/__init__.py")
txt = p.read_text()

needle = "OPENAI_CLIP_MEAN"
if needle in txt:
    print("✅ timm.data already mentions OPENAI_CLIP_MEAN; no patch needed.")
else:
    patch = """

# --- Colab patch: expose CLIP normalization constants for older exports ---
try:
    from .constants import OPENAI_CLIP_MEAN, OPENAI_CLIP_STD  # timm versions where defined in constants
except Exception:
    # Standard OpenAI CLIP normalization
    OPENAI_CLIP_MEAN = (0.48145466, 0.4578275, 0.40821073)
    OPENAI_CLIP_STD  = (0.26862954, 0.26130258, 0.27577711)
# --- end patch ---
"""
    p.write_text(txt + patch)
    print("✅ Patched:", p)
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ✅ Patched: /usr/local/lib/python3.12/dist-packages/timm/data/__init__.py

# %% [markdown]
# Runtime → Restart runtime

# %%
#!pip -q install timm submitit

# %%
# %cd /content/deit
from models import deit_tiny_patch16_224
m = deit_tiny_patch16_224()
print("✅ DeiT model instantiated successfully")
# Out:
# /content/deit
# ✅ DeiT model instantiated successfully

# %%
import torch, timm
print(torch.__version__)
print(timm.__version__)
print(torch.cuda.is_available())
# Out:
# 2.9.0+cu128
# 0.6.13
# True

# %% [markdown]
# Download Tiny-ImageNet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !wget -q http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip
# Out:
# /content
# replace tiny-imagenet-200/words.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# Fix Tiny-ImageNet validation folder

# %%
# !python - << 'EOF'
import shutil
from pathlib import Path

root = Path("/content/tiny-imagenet-200")
val_dir = root/"val"
img_dir = val_dir/"images"
ann = val_dir/"val_annotations.txt"

with ann.open("r") as f:
    for line in f:
        img, cls = line.strip().split("\t")[:2]
        (val_dir/cls).mkdir(parents=True, exist_ok=True)
        src = img_dir/img
        dst = val_dir/cls/img
        if src.exists():
            shutil.move(str(src), str(dst))

if img_dir.exists():
    shutil.rmtree(img_dir)

print("✅ Tiny-ImageNet val reorganized into class subfolders.")
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `EOF')
# ✅ Tiny-ImageNet val reorganized into class subfolders.

# %%
# !find /content/tiny-imagenet-200/val -maxdepth 1 -type d | head
# Out:
# /content/tiny-imagenet-200/val
# /content/tiny-imagenet-200/val/n04417672
# /content/tiny-imagenet-200/val/n04376876
# /content/tiny-imagenet-200/val/n02917067
# /content/tiny-imagenet-200/val/n04074963
# /content/tiny-imagenet-200/val/n07873807
# /content/tiny-imagenet-200/val/n03662601
# /content/tiny-imagenet-200/val/n03804744
# /content/tiny-imagenet-200/val/n03444034
# /content/tiny-imagenet-200/val/n07753592

# %%
ls -lah /content/tiny-imagenet-200 | head
# Out:
# total 2.6M
# drwxrwxr-x   5 root root 4.0K Feb 11 04:16 ./
# drwxr-xr-x   1 root root 4.0K Feb 11 04:14 ../
# drwxrwxr-x   3 root root 4.0K Dec 12  2014 test/
# drwxrwxr-x 202 root root 4.0K Dec 12  2014 train/
# drwxrwxr-x 202 root root 4.0K Feb 11 04:16 val/
# -rw-rw-r--   1 root root 2.0K Feb  9  2015 wnids.txt
# -rw-------   1 root root 2.6M Feb  9  2015 words.txt

# %% [markdown]
# Handle timm incompatibilities. Although we can instantiate the model directly, the training script uses timm.create_model(), which injects metadata arguments such as pretrained_cfg and cache_dir.
# The original DeiT constructors do not support these arguments, so we remove them
# YOUR NOTEBOOK CALL
#     |
#     v
# deit_tiny_patch16_224()          ✅ works (no kwargs)
#
# TRAINING PIPELINE
#     |
#     v
# timm.create_model()
#     |
#     v
# deit_tiny_patch16_224(**kwargs)  ❌ injects extra keys

# %% [markdown]
# Patch /content/deit/augment.py (safe compatibility fix)

# %%
# %cd /content/deit
# !python - << 'PY'
from pathlib import Path
p = Path("augment.py")
txt = p.read_text()

old = "from timm.data.transforms import _pil_interp, RandomResizedCropAndInterpolation, ToNumpy, ToTensor"
if old in txt:
    txt = txt.replace(
        old,
        "from timm.data.transforms import RandomResizedCropAndInterpolation, ToNumpy, ToTensor\n"
        "try:\n"
        "    from timm.data.transforms import _pil_interp  # older timm\n"
        "except Exception:\n"
        "    _pil_interp = None  # newer timm doesn't expose this\n"
    )
    p.write_text(txt)
    print("✅ Patched augment.py for timm compatibility.")
else:
    print("ℹ️ Expected import line not found; augment.py may already be patched or different.")
# Out:
# /content/deit
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# ℹ️ Expected import line not found; augment.py may already be patched or different.

# %%
# %cd /content/deit
# !sed -n '1,200p' models.py
# Out:
# /content/deit
# # Copyright (c) 2015-present, Facebook, Inc.
# # All rights reserved.
# import torch
# import torch.nn as nn
# from functools import partial
#
# from timm.models.vision_transformer import VisionTransformer, _cfg
# from timm.models.registry import register_model
# from timm.models.layers import trunc_normal_
#
#
# __all__ = [
#     'deit_tiny_patch16_224', 'deit_small_patch16_224', 'deit_base_patch16_224',
#     'deit_tiny_distilled_patch16_224', 'deit_small_distilled_patch16_224',
#     'deit_base_distilled_patch16_224', 'deit_base_patch16_384',
#     'deit_base_distilled_patch16_384',
# ]
#
#
# class DistilledVisionTransformer(VisionTransformer):
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#         self.dist_token = nn.Parameter(torch.zeros(1, 1, self.embed_dim))
#         num_patches = self.patch_embed.num_patches
#         self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 2, self.embed_dim))
#         self.head_dist = nn.Linear(self.embed_dim, self.num_classes) if self.num_classes > 0 else nn.Identity()
#
#         trunc_normal_(self.dist_token, std=.02)
#         trunc_normal_(self.pos_embed, std=.02)
#         self.head_dist.apply(self._init_weights)
#
#     def forward_features(self, x):
#         # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#         # with slight modifications to add the dist_token
#         B = x.shape[0]
#         x = self.patch_embed(x)
#
#         cls_tokens = self.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
#         dist_token = self.dist_token.expand(B, -1, -1)
#         x = torch.cat((cls_tokens, dist_token, x), dim=1)
#
#         x = x + self.pos_embed
#         x = self.pos_drop(x)
#
#         for blk in self.blocks:
#             x = blk(x)
#
#         x = self.norm(x)
#         return x[:, 0], x[:, 1]
#
#     def forward(self, x):
#         x, x_dist = self.forward_features(x)
#         x = self.head(x)
#         x_dist = self.head_dist(x_dist)
#         if self.training:
#             return x, x_dist
#         else:
#             # during inference, return the average of both classifier predictions
#             return (x + x_dist) / 2
#
#
# @register_model
# def deit_tiny_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=192, depth=12, num_heads=3, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_small_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=384, depth=12, num_heads=6, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_small_patch16_224-cd65a155.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_base_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = VisionTransformer(
#         patch_size=16, embed_dim=768, depth=12, num_heads=12, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_base_patch16_224-b5f2ef4d.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_tiny_distilled_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = DistilledVisionTransformer(
#         patch_size=16, embed_dim=192, depth=12, num_heads=3, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_tiny_distilled_patch16_224-b40b3cf7.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_small_distilled_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = DistilledVisionTransformer(
#         patch_size=16, embed_dim=384, depth=12, num_heads=6, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_small_distilled_patch16_224-649709d9.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model
# def deit_base_distilled_patch16_224(pretrained=False, **kwargs):
#     # Drop timm-injected kwargs not supported by DeiT
#     kwargs.pop('cache_dir', None)
#     kwargs.pop('hf_hub_id', None)
#     kwargs.pop('hf_hub_filename', None)
#     kwargs.pop('hf_hub_revision', None)
#     kwargs.pop('pretrained_cfg', None)
#     kwargs.pop('pretrained_cfg_overlay', None)
#     kwargs.pop('pretrained_cfg_priority', None)
#     model = DistilledVisionTransformer(
#         patch_size=16, embed_dim=768, depth=12, num_heads=12, mlp_ratio=4, qkv_bias=True,
#         norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     model.default_cfg = _cfg()
#     if pretrained:
#         checkpoint = torch.hub.load_state_dict_from_url(
#             url="https://dl.fbaipublicfiles.com/deit/deit_base_distilled_patch16_224-df68dfff.pth",
#             map_location="cpu", check_hash=True
#         )
#         model.load_state_dict(checkpoint["model"])
#     return model
#
#
# @register_model

# %% [markdown]
# Before constructing the model, remove those keys from kwargs

# %%
from pathlib import Path

p = Path("/content/deit/models.py")
lines = p.read_text().splitlines()

out = []
for line in lines:
    out.append(line)
    if line.strip().startswith("def deit_") and "**kwargs" in line:
        out.append("    # Drop timm-injected kwargs not supported by DeiT")
        out.append("    kwargs.pop('pretrained_cfg', None)")
        out.append("    kwargs.pop('pretrained_cfg_overlay', None)")
        out.append("    kwargs.pop('pretrained_cfg_priority', None)")

p.write_text("\n".join(out) + "\n")
print("✅ models.py patched to drop pretrained_cfg kwargs")
# Out:
# ✅ models.py patched to drop pretrained_cfg kwargs

# %% [markdown]
# Verify

# %%
# !grep -n "pretrained_cfg" /content/deit/models.py
# Out:
# 65:    kwargs.pop('pretrained_cfg', None)
# 66:    kwargs.pop('pretrained_cfg_overlay', None)
# 67:    kwargs.pop('pretrained_cfg_priority', None)
# 73:    kwargs.pop('pretrained_cfg', None)
# 74:    kwargs.pop('pretrained_cfg_overlay', None)
# 75:    kwargs.pop('pretrained_cfg_priority', None)
# 92:    kwargs.pop('pretrained_cfg', None)
# 93:    kwargs.pop('pretrained_cfg_overlay', None)
# 94:    kwargs.pop('pretrained_cfg_priority', None)
# 100:    kwargs.pop('pretrained_cfg', None)
# 101:    kwargs.pop('pretrained_cfg_overlay', None)
# 102:    kwargs.pop('pretrained_cfg_priority', None)
# 119:    kwargs.pop('pretrained_cfg', None)
# 120:    kwargs.pop('pretrained_cfg_overlay', None)
# 121:    kwargs.pop('pretrained_cfg_priority', None)
# 127:    kwargs.pop('pretrained_cfg', None)
# 128:    kwargs.pop('pretrained_cfg_overlay', None)
# 129:    kwargs.pop('pretrained_cfg_priority', None)
# 146:    kwargs.pop('pretrained_cfg', None)
# 147:    kwargs.pop('pretrained_cfg_overlay', None)
# 148:    kwargs.pop('pretrained_cfg_priority', None)
# 154:    kwargs.pop('pretrained_cfg', None)
# 155:    kwargs.pop('pretrained_cfg_overlay', None)
# 156:    kwargs.pop('pretrained_cfg_priority', None)
# 173:    kwargs.pop('pretrained_cfg', None)
# 174:    kwargs.pop('pretrained_cfg_overlay', None)
# 175:    kwargs.pop('pretrained_cfg_priority', None)
# 181:    kwargs.pop('pretrained_cfg', None)
# 182:    kwargs.pop('pretrained_cfg_overlay', None)
# 183:    kwargs.pop('pretrained_cfg_priority', None)
# 200:    kwargs.pop('pretrained_cfg', None)
# 201:    kwargs.pop('pretrained_cfg_overlay', None)
# 202:    kwargs.pop('pretrained_cfg_priority', None)
# 208:    kwargs.pop('pretrained_cfg', None)
# 209:    kwargs.pop('pretrained_cfg_overlay', None)
# 210:    kwargs.pop('pretrained_cfg_priority', None)
# 227:    kwargs.pop('pretrained_cfg', None)
# 228:    kwargs.pop('pretrained_cfg_overlay', None)
# 229:    kwargs.pop('pretrained_cfg_priority', None)
# 235:    kwargs.pop('pretrained_cfg', None)
# 236:    kwargs.pop('pretrained_cfg_overlay', None)
# 237:    kwargs.pop('pretrained_cfg_priority', None)
# 254:    kwargs.pop('pretrained_cfg', None)
# 255:    kwargs.pop('pretrained_cfg_overlay', None)
# 256:    kwargs.pop('pretrained_cfg_priority', None)
# 262:    kwargs.pop('pretrained_cfg', None)
# 263:    kwargs.pop('pretrained_cfg_overlay', None)
# 264:    kwargs.pop('pretrained_cfg_priority', None)

# %% [markdown]
# Fix: Patch /content/deit/models.py to drop pretrained_cfg=...

# %% [markdown]
# Patch models.py to also drop cache_dir (and friends)

# %%
from pathlib import Path

p = Path("/content/deit/models.py")
lines = p.read_text().splitlines()

# Keys that timm may inject but DeiT constructors don't accept
DROP_KEYS = [
    "cache_dir",
    "hf_hub_id",
    "hf_hub_filename",
    "hf_hub_revision",
]

out = []
for line in lines:
    out.append(line)
    # Right after the comment line we previously inserted, add more pops once per function
    if line.strip() == "# Drop timm-injected kwargs not supported by DeiT":
        for k in DROP_KEYS:
            out.append(f"    kwargs.pop('{k}', None)")

p.write_text("\n".join(out) + "\n")
print("✅ Patched models.py to drop cache_dir/hf_hub* kwargs")
# Out:
# ✅ Patched models.py to drop cache_dir/hf_hub* kwargs

# %% [markdown]
# Verify

# %%
# !grep -n "cache_dir" /content/deit/models.py
# Out:
# 65:    kwargs.pop('cache_dir', None)
# 73:    kwargs.pop('cache_dir', None)
# 77:    kwargs.pop('cache_dir', None)
# 100:    kwargs.pop('cache_dir', None)
# 108:    kwargs.pop('cache_dir', None)
# 112:    kwargs.pop('cache_dir', None)
# 135:    kwargs.pop('cache_dir', None)
# 143:    kwargs.pop('cache_dir', None)
# 147:    kwargs.pop('cache_dir', None)
# 170:    kwargs.pop('cache_dir', None)
# 178:    kwargs.pop('cache_dir', None)
# 182:    kwargs.pop('cache_dir', None)
# 205:    kwargs.pop('cache_dir', None)
# 213:    kwargs.pop('cache_dir', None)
# 217:    kwargs.pop('cache_dir', None)
# 240:    kwargs.pop('cache_dir', None)
# 248:    kwargs.pop('cache_dir', None)
# 252:    kwargs.pop('cache_dir', None)
# 275:    kwargs.pop('cache_dir', None)
# 283:    kwargs.pop('cache_dir', None)
# 287:    kwargs.pop('cache_dir', None)
# 310:    kwargs.pop('cache_dir', None)
# 318:    kwargs.pop('cache_dir', None)
# 322:    kwargs.pop('cache_dir', None)

# %%
# %cd /content/deit
# !python main.py \
#   --model deit_tiny_patch16_224 \
#   --data-path /content/tiny-imagenet-200 \
#   --pretrained \
#   --epochs 1 \
#   --batch-size 64 \
#   --num_workers 2 \
#   --output_dir /content/deit_runs/smoke_test
# %cd /content/deit
# !python main.py \
#   --model deit_tiny_patch16_224 \
#   --data-path /content/tiny-imagenet-200 \
#   --epochs 1 \
#   --batch-size 128 \
#   --num_workers 4 \
#   --input-size 224 \
#   --opt adamw \
#   --lr 5e-4 \
#   --weight-decay 0.05 \
#   --sched cosine \
#   --aa rand-m9-mstd0.5 \
#   --reprob 0.25 \
#   --remode pixel \
#   --recount 1 \
#   --output_dir /content/deit_runs/tiny_imagenet
# %cd /content/deit
# !python main.py \
#  --model deit_tiny_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 3e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.1 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.1 \
#  --output_dir /content/deit_runs/tiny_imagenet_5ep
# %cd /content/deit
# !python main.py \
  --model deit_tiny_distilled_patch16_224 \
  --data-path /content/tiny-imagenet-200 \
  --input-size 224 \
  --epochs 100 \
  --batch-size 1024 \
  --opt adamw \
  --lr 0.001 \
  --sched cosine \
  --warmup-epochs 5 \
  --weight-decay 0.05 \
  --smoothing 0.1 \
  --drop 0.0 \
  --drop-path 0.1 \
  --repeated-aug \
  --aa rand-m9-mstd0.5-inc1 \
  --mixup 0.8 \
  --cutmix 1.0 \
  --reprob 0.25 \
  --distillation-type soft \
  --distillation-alpha 0.1 \
  --distillation-tau 3.0 \
  --teacher-model regnety_160 \
  --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
  --output_dir /content/deit_runs/paper_recipe

# %cd /content/deit
# !python main.py \
#  --model deit_tiny_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 2.5e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.1 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.1 \
#  --distillation-type hard \
# --teacher-model regnety_160 \
# --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
#  --output_dir /content/deit_runs/tiny_imagenet_10ep
# %cd /content/deit
# !python main.py \
#  --model deit_tiny_distilled_patch16_224 \
#  --data-path /content/tiny-imagenet-200 \
#  --epochs 10 \
#  --batch-size 128 \
#  --num_workers 4 \
#  --input-size 224 \
#  --opt adamw \
#  --lr 7e-4 \
#  --weight-decay 0.05 \
#  --sched cosine \
#  --warmup-epochs 1 \
#  --smoothing 0.0 \
#  --aa rand-m7-mstd0.5 \
#  --reprob 0.1 \
#  --drop-path 0.0 \
#  --distillation-type hard \
#  --distillation-alpha 0.7 \
#  --teacher-model regnety_160 \
#  --teacher-path https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth \
#  --output_dir /content/deit_runs/deit_tiny_distilled_10ep
# Out:
# /content/deit
# Not using distributed mode
# Namespace(batch_size=1024, epochs=100, bce_loss=False, unscale_lr=False, model='deit_tiny_distilled_patch16_224', input_size=224, drop=0.0, drop_path=0.1, model_ema=True, model_ema_decay=0.99996, model_ema_force_cpu=False, opt='adamw', opt_eps=1e-08, opt_betas=None, clip_grad=None, momentum=0.9, weight_decay=0.05, sched='cosine', lr=0.001, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=5, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, color_jitter=0.3, aa='rand-m9-mstd0.5-inc1', smoothing=0.1, train_interpolation='bicubic', repeated_aug=True, train_mode=True, ThreeAugment=False, src=False, reprob=0.25, remode='pixel', recount=1, resplit=False, mixup=0.8, cutmix=1.0, cutmix_minmax=None, mixup_prob=1.0, mixup_switch_prob=0.5, mixup_mode='batch', teacher_model='regnety_160', teacher_path='https://dl.fbaipublicfiles.com/deit/regnety_160-a5fe301d.pth', distillation_type='soft', distillation_alpha=0.1, distillation_tau=3.0, cosub=False, finetune='', attn_only=False, data_path='/content/tiny-imagenet-200', data_set='IMNET', inat_category='name', output_dir='/content/deit_runs/paper_recipe', device='cuda', seed=0, resume='', start_epoch=0, eval=False, eval_crop_ratio=0.875, dist_eval=False, num_workers=10, pin_mem=True, distributed=False, world_size=1, dist_url='env://')
# Creating model: deit_tiny_distilled_patch16_224
# number of params: 5910800
# /usr/local/lib/python3.12/dist-packages/timm/utils/cuda.py:40: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self._scaler = torch.cuda.amp.GradScaler()
# Creating teacher model: regnety_160
# Start training for 100 epochs
# /content/deit/engine.py:46: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch: [0]  [ 0/97]  eta: 0:40:19  lr: 0.000001  loss: 6.2541 (6.2541)  time: 24.9385  data: 12.4080  max mem: 46135
# Epoch: [0]  [10/97]  eta: 0:04:20  lr: 0.000001  loss: 6.2401 (6.2407)  time: 2.9948  data: 1.1285  max mem: 46135
# Epoch: [0]  [20/97]  eta: 0:02:29  lr: 0.000001  loss: 6.2359 (6.2372)  time: 0.7984  data: 0.0006  max mem: 46135
# Epoch: [0]  [30/97]  eta: 0:01:45  lr: 0.000001  loss: 6.2318 (6.2337)  time: 0.7985  data: 0.0007  max mem: 46135
# Epoch: [0]  [40/97]  eta: 0:01:19  lr: 0.000001  loss: 6.2215 (6.2283)  time: 0.7998  data: 0.0007  max mem: 46135
# Epoch: [0]  [50/97]  eta: 0:00:59  lr: 0.000001  loss: 6.2054 (6.2234)  time: 0.7992  data: 0.0007  max mem: 46135
# Epoch: [0]  [60/97]  eta: 0:00:44  lr: 0.000001  loss: 6.2007 (6.2190)  time: 0.8004  data: 0.0006  max mem: 46135
# Epoch: [0]  [70/97]  eta: 0:00:30  lr: 0.000001  loss: 6.1920 (6.2145)  time: 0.7992  data: 0.0005  max mem: 46135
# Epoch: [0]  [80/97]  eta: 0:00:18  lr: 0.000001  loss: 6.1790 (6.2096)  time: 0.7993  data: 0.0013  max mem: 46135
# Epoch: [0]  [90/97]  eta: 0:00:07  lr: 0.000001  loss: 6.1710 (6.2053)  time: 0.7986  data: 0.0011  max mem: 46135
# Epoch: [0]  [96/97]  eta: 0:00:01  lr: 0.000001  loss: 6.1699 (6.2028)  time: 0.7966  data: 0.0011  max mem: 46135
# Epoch: [0] Total time: 0:01:41 (1.0488 s / it)
# Averaged stats: lr: 0.000001  loss: 6.1699 (6.2028)
# /content/deit/engine.py:97: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Test:  [0/7]  eta: 0:00:46  loss: 6.8697 (6.8697)  acc1: 0.3255 (0.3255)  acc5: 2.1484 (2.1484)  time: 6.6343  data: 6.0788  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 6.8697 (6.8714)  acc1: 0.0651 (0.1700)  acc5: 0.4557 (1.1800)  time: 1.1882  data: 0.8919  max mem: 46135
# Test: Total time: 0:00:08 (1.2148 s / it)
# * Acc@1 0.170 Acc@5 1.180 loss 6.871
# Accuracy of the network on the 10000 test images: 0.2%
# Max accuracy: 0.17%
# Epoch: [1]  [ 0/97]  eta: 0:13:27  lr: 0.000001  loss: 6.1843 (6.1843)  time: 8.3242  data: 7.5054  max mem: 46135
# Epoch: [1]  [10/97]  eta: 0:02:15  lr: 0.000001  loss: 6.1578 (6.1592)  time: 1.5563  data: 0.7518  max mem: 46135
# Epoch: [1]  [20/97]  eta: 0:01:32  lr: 0.000001  loss: 6.1534 (6.1540)  time: 0.8415  data: 0.0385  max mem: 46135
# Epoch: [1]  [30/97]  eta: 0:01:11  lr: 0.000001  loss: 6.1449 (6.1498)  time: 0.8020  data: 0.0005  max mem: 46135
# Epoch: [1]  [40/97]  eta: 0:00:57  lr: 0.000001  loss: 6.1341 (6.1444)  time: 0.7993  data: 0.0006  max mem: 46135
# Epoch: [1]  [50/97]  eta: 0:00:45  lr: 0.000001  loss: 6.1269 (6.1414)  time: 0.7975  data: 0.0006  max mem: 46135
# Epoch: [1]  [60/97]  eta: 0:00:34  lr: 0.000001  loss: 6.1223 (6.1378)  time: 0.7987  data: 0.0005  max mem: 46135
# Epoch: [1]  [70/97]  eta: 0:00:24  lr: 0.000001  loss: 6.1167 (6.1344)  time: 0.7988  data: 0.0006  max mem: 46135
# Epoch: [1]  [80/97]  eta: 0:00:15  lr: 0.000001  loss: 6.1109 (6.1313)  time: 0.7986  data: 0.0012  max mem: 46135
# Epoch: [1]  [90/97]  eta: 0:00:06  lr: 0.000001  loss: 6.1027 (6.1280)  time: 0.7978  data: 0.0010  max mem: 46135
# Epoch: [1]  [96/97]  eta: 0:00:00  lr: 0.000001  loss: 6.1017 (6.1262)  time: 0.7961  data: 0.0008  max mem: 46135
# Epoch: [1] Total time: 0:01:26 (0.8875 s / it)
# Averaged stats: lr: 0.000001  loss: 6.1017 (6.1262)
# Test:  [0/7]  eta: 0:00:46  loss: 6.8245 (6.8245)  acc1: 0.5208 (0.5208)  acc5: 2.0182 (2.0182)  time: 6.6386  data: 6.4133  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 6.8276 (6.8244)  acc1: 0.0000 (0.2600)  acc5: 1.4323 (1.4000)  time: 1.1775  data: 0.9831  max mem: 46135
# Test: Total time: 0:00:08 (1.1899 s / it)
# * Acc@1 0.260 Acc@5 1.400 loss 6.824
# Accuracy of the network on the 10000 test images: 0.3%
# Max accuracy: 0.26%
# Epoch: [2]  [ 0/97]  eta: 0:15:10  lr: 0.000401  loss: 6.1006 (6.1006)  time: 9.3832  data: 8.3094  max mem: 46135
# Epoch: [2]  [10/97]  eta: 0:02:17  lr: 0.000401  loss: 5.6840 (5.6994)  time: 1.5819  data: 0.7559  max mem: 46135
# Epoch: [2]  [20/97]  eta: 0:01:33  lr: 0.000401  loss: 5.3131 (5.4662)  time: 0.8022  data: 0.0008  max mem: 46135
# Epoch: [2]  [30/97]  eta: 0:01:12  lr: 0.000401  loss: 5.1399 (5.3573)  time: 0.8018  data: 0.0008  max mem: 46135
# Epoch: [2]  [40/97]  eta: 0:00:57  lr: 0.000401  loss: 5.1241 (5.2998)  time: 0.8000  data: 0.0006  max mem: 46135
# Epoch: [2]  [50/97]  eta: 0:00:45  lr: 0.000401  loss: 5.1236 (5.2910)  time: 0.7988  data: 0.0005  max mem: 46135
# Epoch: [2]  [60/97]  eta: 0:00:34  lr: 0.000401  loss: 5.1249 (5.2634)  time: 0.7995  data: 0.0005  max mem: 46135
# Epoch: [2]  [70/97]  eta: 0:00:24  lr: 0.000401  loss: 5.1210 (5.2432)  time: 0.8005  data: 0.0005  max mem: 46135
# Epoch: [2]  [80/97]  eta: 0:00:15  lr: 0.000401  loss: 5.1184 (5.2275)  time: 0.7984  data: 0.0008  max mem: 46135
# Epoch: [2]  [90/97]  eta: 0:00:06  lr: 0.000401  loss: 5.1152 (5.2152)  time: 0.7956  data: 0.0007  max mem: 46135
# Epoch: [2]  [96/97]  eta: 0:00:00  lr: 0.000401  loss: 5.1119 (5.2083)  time: 0.7950  data: 0.0006  max mem: 46135
# Epoch: [2] Total time: 0:01:26 (0.8912 s / it)
# Averaged stats: lr: 0.000401  loss: 5.1119 (5.2083)
# Test:  [0/7]  eta: 0:00:40  loss: 5.9736 (5.9736)  acc1: 0.0000 (0.0000)  acc5: 0.0000 (0.0000)  time: 5.7935  data: 5.5682  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.8544 (5.8168)  acc1: 0.0000 (0.6800)  acc5: 4.2318 (3.6800)  time: 1.1667  data: 0.9722  max mem: 46135
# Test: Total time: 0:00:08 (1.1773 s / it)
# * Acc@1 0.680 Acc@5 3.680 loss 5.817
# Accuracy of the network on the 10000 test images: 0.7%
# Max accuracy: 0.68%
# Epoch: [3]  [ 0/97]  eta: 0:13:39  lr: 0.000801  loss: 5.0931 (5.0931)  time: 8.4522  data: 7.6352  max mem: 46135
# Epoch: [3]  [10/97]  eta: 0:02:10  lr: 0.000801  loss: 5.1025 (5.1050)  time: 1.4969  data: 0.6945  max mem: 46135
# Epoch: [3]  [20/97]  eta: 0:01:29  lr: 0.000801  loss: 5.1025 (5.1022)  time: 0.8023  data: 0.0007  max mem: 46135
# Epoch: [3]  [30/97]  eta: 0:01:10  lr: 0.000801  loss: 5.1041 (5.1032)  time: 0.8029  data: 0.0008  max mem: 46135
# Epoch: [3]  [40/97]  eta: 0:00:56  lr: 0.000801  loss: 5.1028 (5.1007)  time: 0.8013  data: 0.0006  max mem: 46135
# Epoch: [3]  [50/97]  eta: 0:00:44  lr: 0.000801  loss: 5.0922 (5.0993)  time: 0.8011  data: 0.0005  max mem: 46135
# Epoch: [3]  [60/97]  eta: 0:00:34  lr: 0.000801  loss: 5.0901 (5.0977)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [3]  [70/97]  eta: 0:00:24  lr: 0.000801  loss: 5.0840 (5.0955)  time: 0.7987  data: 0.0005  max mem: 46135
# Epoch: [3]  [80/97]  eta: 0:00:15  lr: 0.000801  loss: 5.0747 (5.0923)  time: 0.7982  data: 0.0008  max mem: 46135
# Epoch: [3]  [90/97]  eta: 0:00:06  lr: 0.000801  loss: 5.0663 (5.0886)  time: 0.7968  data: 0.0007  max mem: 46135
# Epoch: [3]  [96/97]  eta: 0:00:00  lr: 0.000801  loss: 5.0561 (5.0858)  time: 0.7959  data: 0.0005  max mem: 46135
# Epoch: [3] Total time: 0:01:25 (0.8817 s / it)
# Averaged stats: lr: 0.000801  loss: 5.0561 (5.0858)
# Test:  [0/7]  eta: 0:00:42  loss: 5.8655 (5.8655)  acc1: 0.0000 (0.0000)  acc5: 0.0000 (0.0000)  time: 6.1209  data: 5.8958  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.7404 (5.6887)  acc1: 1.2370 (1.5200)  acc5: 5.4688 (6.1600)  time: 1.1317  data: 0.9373  max mem: 46135
# Test: Total time: 0:00:07 (1.1428 s / it)
# * Acc@1 1.520 Acc@5 6.160 loss 5.689
# Accuracy of the network on the 10000 test images: 1.5%
# Max accuracy: 1.52%
# Epoch: [4]  [ 0/97]  eta: 0:16:17  lr: 0.001200  loss: 5.0690 (5.0690)  time: 10.0756  data: 9.2483  max mem: 46135
# Epoch: [4]  [10/97]  eta: 0:02:22  lr: 0.001200  loss: 5.0690 (5.0647)  time: 1.6402  data: 0.8414  max mem: 46135
# Epoch: [4]  [20/97]  eta: 0:01:35  lr: 0.001200  loss: 5.0651 (5.0660)  time: 0.7986  data: 0.0006  max mem: 46135
# Epoch: [4]  [30/97]  eta: 0:01:13  lr: 0.001200  loss: 5.0613 (5.0568)  time: 0.8005  data: 0.0005  max mem: 46135
# Epoch: [4]  [40/97]  eta: 0:00:58  lr: 0.001200  loss: 5.0534 (5.0565)  time: 0.8013  data: 0.0006  max mem: 46135
# Epoch: [4]  [50/97]  eta: 0:00:46  lr: 0.001200  loss: 5.0534 (5.0554)  time: 0.7999  data: 0.0006  max mem: 46135
# Epoch: [4]  [60/97]  eta: 0:00:35  lr: 0.001200  loss: 5.0406 (5.0528)  time: 0.7998  data: 0.0006  max mem: 46135
# Epoch: [4]  [70/97]  eta: 0:00:25  lr: 0.001200  loss: 5.0231 (5.0463)  time: 0.8010  data: 0.0006  max mem: 46135
# Epoch: [4]  [80/97]  eta: 0:00:15  lr: 0.001200  loss: 5.0002 (5.0402)  time: 0.7997  data: 0.0009  max mem: 46135
# Epoch: [4]  [90/97]  eta: 0:00:06  lr: 0.001200  loss: 5.0002 (5.0362)  time: 0.7974  data: 0.0007  max mem: 46135
# Epoch: [4]  [96/97]  eta: 0:00:00  lr: 0.001200  loss: 5.0105 (5.0355)  time: 0.7963  data: 0.0006  max mem: 46135
# Epoch: [4] Total time: 0:01:27 (0.8982 s / it)
# Averaged stats: lr: 0.001200  loss: 5.0105 (5.0355)
# Test:  [0/7]  eta: 0:00:49  loss: 5.7546 (5.7546)  acc1: 0.2604 (0.2604)  acc5: 2.2786 (2.2786)  time: 7.1323  data: 6.9121  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.6905 (5.6047)  acc1: 1.6927 (2.1400)  acc5: 5.9896 (7.4400)  time: 1.1814  data: 0.9877  max mem: 46135
# Test: Total time: 0:00:08 (1.1935 s / it)
# * Acc@1 2.140 Acc@5 7.440 loss 5.605
# Accuracy of the network on the 10000 test images: 2.1%
# Max accuracy: 2.14%
# Epoch: [5]  [ 0/97]  eta: 0:13:40  lr: 0.001600  loss: 5.0620 (5.0620)  time: 8.4635  data: 7.6315  max mem: 46135
# Epoch: [5]  [10/97]  eta: 0:02:11  lr: 0.001600  loss: 5.0184 (5.0175)  time: 1.5101  data: 0.7051  max mem: 46135
# Epoch: [5]  [20/97]  eta: 0:01:30  lr: 0.001600  loss: 5.0184 (5.0157)  time: 0.8084  data: 0.0065  max mem: 46135
# Epoch: [5]  [30/97]  eta: 0:01:10  lr: 0.001600  loss: 5.0312 (5.0228)  time: 0.8021  data: 0.0006  max mem: 46135
# Epoch: [5]  [40/97]  eta: 0:00:56  lr: 0.001600  loss: 5.0262 (5.0139)  time: 0.8022  data: 0.0006  max mem: 46135
# Epoch: [5]  [50/97]  eta: 0:00:44  lr: 0.001600  loss: 5.0053 (5.0089)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [5]  [60/97]  eta: 0:00:34  lr: 0.001600  loss: 5.0050 (5.0057)  time: 0.7998  data: 0.0005  max mem: 46135
# Epoch: [5]  [70/97]  eta: 0:00:24  lr: 0.001600  loss: 5.0077 (5.0062)  time: 0.8021  data: 0.0006  max mem: 46135
# Epoch: [5]  [80/97]  eta: 0:00:15  lr: 0.001600  loss: 5.0217 (5.0065)  time: 0.8017  data: 0.0011  max mem: 46135
# Epoch: [5]  [90/97]  eta: 0:00:06  lr: 0.001600  loss: 5.0139 (5.0048)  time: 0.7973  data: 0.0009  max mem: 46135
# Epoch: [5]  [96/97]  eta: 0:00:00  lr: 0.001600  loss: 4.9895 (5.0045)  time: 0.7960  data: 0.0008  max mem: 46135
# Epoch: [5] Total time: 0:01:25 (0.8834 s / it)
# Averaged stats: lr: 0.001600  loss: 4.9895 (5.0045)
# Test:  [0/7]  eta: 0:00:47  loss: 5.6683 (5.6683)  acc1: 0.8464 (0.8464)  acc5: 5.0130 (5.0130)  time: 6.7398  data: 6.5179  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.6115 (5.5300)  acc1: 2.6042 (1.9900)  acc5: 8.3333 (8.7000)  time: 1.1254  data: 0.9313  max mem: 46135
# Test: Total time: 0:00:07 (1.1361 s / it)
# * Acc@1 1.990 Acc@5 8.700 loss 5.530
# Accuracy of the network on the 10000 test images: 2.0%
# Max accuracy: 2.14%
# Epoch: [6]  [ 0/97]  eta: 0:15:14  lr: 0.001988  loss: 5.0461 (5.0461)  time: 9.4307  data: 8.6083  max mem: 46135
# Epoch: [6]  [10/97]  eta: 0:02:17  lr: 0.001988  loss: 5.0265 (5.0075)  time: 1.5855  data: 0.7830  max mem: 46135
# Epoch: [6]  [20/97]  eta: 0:01:33  lr: 0.001988  loss: 4.9826 (4.9890)  time: 0.8017  data: 0.0006  max mem: 46135
# Epoch: [6]  [30/97]  eta: 0:01:12  lr: 0.001988  loss: 4.9826 (4.9954)  time: 0.8018  data: 0.0008  max mem: 46135
# Epoch: [6]  [40/97]  eta: 0:00:57  lr: 0.001988  loss: 5.0003 (4.9967)  time: 0.8001  data: 0.0007  max mem: 46135
# Epoch: [6]  [50/97]  eta: 0:00:45  lr: 0.001988  loss: 5.0062 (4.9960)  time: 0.8003  data: 0.0006  max mem: 46135
# Epoch: [6]  [60/97]  eta: 0:00:34  lr: 0.001988  loss: 4.9754 (4.9923)  time: 0.8012  data: 0.0006  max mem: 46135
# Epoch: [6]  [70/97]  eta: 0:00:24  lr: 0.001988  loss: 4.9721 (4.9901)  time: 0.8014  data: 0.0006  max mem: 46135
# Epoch: [6]  [80/97]  eta: 0:00:15  lr: 0.001988  loss: 4.9467 (4.9840)  time: 0.8020  data: 0.0015  max mem: 46135
# Epoch: [6]  [90/97]  eta: 0:00:06  lr: 0.001988  loss: 4.9716 (4.9845)  time: 0.7993  data: 0.0012  max mem: 46135
# Epoch: [6]  [96/97]  eta: 0:00:00  lr: 0.001988  loss: 4.9716 (4.9830)  time: 0.7972  data: 0.0011  max mem: 46135
# Epoch: [6] Total time: 0:01:26 (0.8923 s / it)
# Averaged stats: lr: 0.001988  loss: 4.9716 (4.9830)
# Test:  [0/7]  eta: 0:00:49  loss: 5.6308 (5.6308)  acc1: 2.1484 (2.1484)  acc5: 8.5938 (8.5938)  time: 7.1300  data: 6.9041  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.5874 (5.5073)  acc1: 2.4740 (2.9900)  acc5: 8.9844 (10.8300)  time: 1.1813  data: 0.9865  max mem: 46135
# Test: Total time: 0:00:08 (1.1930 s / it)
# * Acc@1 2.990 Acc@5 10.830 loss 5.507
# Accuracy of the network on the 10000 test images: 3.0%
# Max accuracy: 2.99%
# Epoch: [7]  [ 0/97]  eta: 0:11:10  lr: 0.001982  loss: 4.9576 (4.9576)  time: 6.9148  data: 6.0796  max mem: 46135
# Epoch: [7]  [10/97]  eta: 0:02:02  lr: 0.001982  loss: 4.9506 (4.9459)  time: 1.4055  data: 0.5980  max mem: 46135
# Epoch: [7]  [20/97]  eta: 0:01:26  lr: 0.001982  loss: 4.9340 (4.9455)  time: 0.8287  data: 0.0252  max mem: 46135
# Epoch: [7]  [30/97]  eta: 0:01:08  lr: 0.001982  loss: 4.9825 (4.9572)  time: 0.8029  data: 0.0006  max mem: 46135
# Epoch: [7]  [40/97]  eta: 0:00:54  lr: 0.001982  loss: 4.9786 (4.9472)  time: 0.8013  data: 0.0006  max mem: 46135
# Epoch: [7]  [50/97]  eta: 0:00:43  lr: 0.001982  loss: 4.9249 (4.9472)  time: 0.8013  data: 0.0006  max mem: 46135
# Epoch: [7]  [60/97]  eta: 0:00:33  lr: 0.001982  loss: 4.9941 (4.9587)  time: 0.8013  data: 0.0006  max mem: 46135
# Epoch: [7]  [70/97]  eta: 0:00:24  lr: 0.001982  loss: 5.0041 (4.9586)  time: 0.8014  data: 0.0005  max mem: 46135
# Epoch: [7]  [80/97]  eta: 0:00:15  lr: 0.001982  loss: 4.9863 (4.9585)  time: 0.8014  data: 0.0010  max mem: 46135
# Epoch: [7]  [90/97]  eta: 0:00:06  lr: 0.001982  loss: 4.9763 (4.9603)  time: 0.7974  data: 0.0008  max mem: 46135
# Epoch: [7]  [96/97]  eta: 0:00:00  lr: 0.001982  loss: 4.9810 (4.9608)  time: 0.7962  data: 0.0006  max mem: 46135
# Epoch: [7] Total time: 0:01:24 (0.8717 s / it)
# Averaged stats: lr: 0.001982  loss: 4.9810 (4.9608)
# Test:  [0/7]  eta: 0:00:46  loss: 5.6090 (5.6090)  acc1: 2.3438 (2.3438)  acc5: 10.0260 (10.0260)  time: 6.6899  data: 6.4626  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.5795 (5.4890)  acc1: 2.6042 (3.7200)  acc5: 10.0260 (12.4600)  time: 1.1396  data: 0.9439  max mem: 46135
# Test: Total time: 0:00:08 (1.1523 s / it)
# * Acc@1 3.720 Acc@5 12.460 loss 5.489
# Accuracy of the network on the 10000 test images: 3.7%
# Max accuracy: 3.72%
# Epoch: [8]  [ 0/97]  eta: 0:15:56  lr: 0.001976  loss: 4.8998 (4.8998)  time: 9.8655  data: 9.0506  max mem: 46135
# Epoch: [8]  [10/97]  eta: 0:02:21  lr: 0.001976  loss: 4.9352 (4.9276)  time: 1.6241  data: 0.8232  max mem: 46135
# Epoch: [8]  [20/97]  eta: 0:01:34  lr: 0.001976  loss: 4.9563 (4.9382)  time: 0.8005  data: 0.0005  max mem: 46135
# Epoch: [8]  [30/97]  eta: 0:01:13  lr: 0.001976  loss: 4.9452 (4.9342)  time: 0.8020  data: 0.0005  max mem: 46135
# Epoch: [8]  [40/97]  eta: 0:00:58  lr: 0.001976  loss: 4.9452 (4.9340)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [8]  [50/97]  eta: 0:00:45  lr: 0.001976  loss: 4.8996 (4.9288)  time: 0.7987  data: 0.0005  max mem: 46135
# Epoch: [8]  [60/97]  eta: 0:00:35  lr: 0.001976  loss: 4.8996 (4.9279)  time: 0.7992  data: 0.0005  max mem: 46135
# Epoch: [8]  [70/97]  eta: 0:00:25  lr: 0.001976  loss: 4.9209 (4.9265)  time: 0.8009  data: 0.0005  max mem: 46135
# Epoch: [8]  [80/97]  eta: 0:00:15  lr: 0.001976  loss: 4.9596 (4.9280)  time: 0.8022  data: 0.0009  max mem: 46135
# Epoch: [8]  [90/97]  eta: 0:00:06  lr: 0.001976  loss: 4.9541 (4.9271)  time: 0.7991  data: 0.0007  max mem: 46135
# Epoch: [8]  [96/97]  eta: 0:00:00  lr: 0.001976  loss: 4.9529 (4.9277)  time: 0.7972  data: 0.0006  max mem: 46135
# Epoch: [8] Total time: 0:01:26 (0.8965 s / it)
# Averaged stats: lr: 0.001976  loss: 4.9529 (4.9277)
# Test:  [0/7]  eta: 0:00:44  loss: 5.5830 (5.5830)  acc1: 1.9531 (1.9531)  acc5: 10.8724 (10.8724)  time: 6.3548  data: 6.1272  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.4894 (5.4268)  acc1: 3.7760 (4.1200)  acc5: 12.8255 (14.3500)  time: 1.1450  data: 0.9486  max mem: 46135
# Test: Total time: 0:00:08 (1.1556 s / it)
# * Acc@1 4.120 Acc@5 14.350 loss 5.427
# Accuracy of the network on the 10000 test images: 4.1%
# Max accuracy: 4.12%
# Epoch: [9]  [ 0/97]  eta: 0:12:56  lr: 0.001969  loss: 5.0114 (5.0114)  time: 8.0079  data: 7.1756  max mem: 46135
# Epoch: [9]  [10/97]  eta: 0:02:16  lr: 0.001969  loss: 4.9236 (4.9192)  time: 1.5686  data: 0.7630  max mem: 46135
# Epoch: [9]  [20/97]  eta: 0:01:32  lr: 0.001969  loss: 4.8912 (4.9096)  time: 0.8635  data: 0.0611  max mem: 46135
# Epoch: [9]  [30/97]  eta: 0:01:11  lr: 0.001969  loss: 4.9116 (4.9164)  time: 0.8008  data: 0.0005  max mem: 46135
# Epoch: [9]  [40/97]  eta: 0:00:57  lr: 0.001969  loss: 4.9570 (4.9159)  time: 0.8001  data: 0.0005  max mem: 46135
# Epoch: [9]  [50/97]  eta: 0:00:45  lr: 0.001969  loss: 4.9736 (4.9274)  time: 0.7995  data: 0.0005  max mem: 46135
# Epoch: [9]  [60/97]  eta: 0:00:34  lr: 0.001969  loss: 4.9786 (4.9320)  time: 0.7999  data: 0.0005  max mem: 46135
# Epoch: [9]  [70/97]  eta: 0:00:24  lr: 0.001969  loss: 4.9297 (4.9259)  time: 0.8006  data: 0.0006  max mem: 46135
# Epoch: [9]  [80/97]  eta: 0:00:15  lr: 0.001969  loss: 4.8890 (4.9210)  time: 0.8006  data: 0.0009  max mem: 46135
# Epoch: [9]  [90/97]  eta: 0:00:06  lr: 0.001969  loss: 4.9097 (4.9221)  time: 0.7996  data: 0.0007  max mem: 46135
# Epoch: [9]  [96/97]  eta: 0:00:00  lr: 0.001969  loss: 4.9506 (4.9258)  time: 0.7980  data: 0.0006  max mem: 46135
# Epoch: [9] Total time: 0:01:26 (0.8906 s / it)
# Averaged stats: lr: 0.001969  loss: 4.9506 (4.9258)
# Test:  [0/7]  eta: 0:00:42  loss: 5.6438 (5.6438)  acc1: 0.7812 (0.7812)  acc5: 5.8594 (5.8594)  time: 6.0374  data: 5.8199  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.5515 (5.4739)  acc1: 3.3854 (3.3700)  acc5: 10.0911 (11.1100)  time: 1.1548  data: 0.9586  max mem: 46135
# Test: Total time: 0:00:08 (1.1754 s / it)
# * Acc@1 3.370 Acc@5 11.110 loss 5.474
# Accuracy of the network on the 10000 test images: 3.4%
# Max accuracy: 4.12%
# Epoch: [10]  [ 0/97]  eta: 0:13:17  lr: 0.001960  loss: 4.9126 (4.9126)  time: 8.2166  data: 7.3917  max mem: 46135
# Epoch: [10]  [10/97]  eta: 0:02:13  lr: 0.001960  loss: 4.9656 (4.9375)  time: 1.5325  data: 0.7233  max mem: 46135
# Epoch: [10]  [20/97]  eta: 0:01:31  lr: 0.001960  loss: 4.9674 (4.9308)  time: 0.8337  data: 0.0285  max mem: 46135
# Epoch: [10]  [30/97]  eta: 0:01:11  lr: 0.001960  loss: 4.9466 (4.9266)  time: 0.8045  data: 0.0008  max mem: 46135
# Epoch: [10]  [40/97]  eta: 0:00:56  lr: 0.001960  loss: 4.9466 (4.9299)  time: 0.8052  data: 0.0008  max mem: 46135
# Epoch: [10]  [50/97]  eta: 0:00:45  lr: 0.001960  loss: 4.9401 (4.9226)  time: 0.8032  data: 0.0006  max mem: 46135
# Epoch: [10]  [60/97]  eta: 0:00:34  lr: 0.001960  loss: 4.9121 (4.9164)  time: 0.8021  data: 0.0005  max mem: 46135
# Epoch: [10]  [70/97]  eta: 0:00:24  lr: 0.001960  loss: 4.9127 (4.9187)  time: 0.8031  data: 0.0006  max mem: 46135
# Epoch: [10]  [80/97]  eta: 0:00:15  lr: 0.001960  loss: 4.9318 (4.9196)  time: 0.8019  data: 0.0010  max mem: 46135
# Epoch: [10]  [90/97]  eta: 0:00:06  lr: 0.001960  loss: 4.9538 (4.9230)  time: 0.7983  data: 0.0008  max mem: 46135
# Epoch: [10]  [96/97]  eta: 0:00:00  lr: 0.001960  loss: 4.9501 (4.9225)  time: 0.7978  data: 0.0007  max mem: 46135
# Epoch: [10] Total time: 0:01:26 (0.8877 s / it)
# Averaged stats: lr: 0.001960  loss: 4.9501 (4.9225)
# Test:  [0/7]  eta: 0:00:50  loss: 5.4845 (5.4845)  acc1: 3.2552 (3.2552)  acc5: 10.9375 (10.9375)  time: 7.2656  data: 7.0480  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.4126 (5.3507)  acc1: 4.8177 (5.4700)  acc5: 14.2578 (15.9700)  time: 1.2030  data: 1.0071  max mem: 46135
# Test: Total time: 0:00:08 (1.2171 s / it)
# * Acc@1 5.470 Acc@5 15.970 loss 5.351
# Accuracy of the network on the 10000 test images: 5.5%
# Max accuracy: 5.47%
# Epoch: [11]  [ 0/97]  eta: 0:10:27  lr: 0.001951  loss: 4.9834 (4.9834)  time: 6.4715  data: 5.6476  max mem: 46135
# Epoch: [11]  [10/97]  eta: 0:02:06  lr: 0.001951  loss: 4.9323 (4.9035)  time: 1.4549  data: 0.6483  max mem: 46135
# Epoch: [11]  [20/97]  eta: 0:01:28  lr: 0.001951  loss: 4.9272 (4.9057)  time: 0.8796  data: 0.0745  max mem: 46135
# Epoch: [11]  [30/97]  eta: 0:01:09  lr: 0.001951  loss: 4.9326 (4.9067)  time: 0.8041  data: 0.0005  max mem: 46135
# Epoch: [11]  [40/97]  eta: 0:00:55  lr: 0.001951  loss: 4.9451 (4.9113)  time: 0.8024  data: 0.0005  max mem: 46135
# Epoch: [11]  [50/97]  eta: 0:00:44  lr: 0.001951  loss: 4.9506 (4.9148)  time: 0.8024  data: 0.0005  max mem: 46135
# Epoch: [11]  [60/97]  eta: 0:00:34  lr: 0.001951  loss: 4.9139 (4.9139)  time: 0.8014  data: 0.0005  max mem: 46135
# Epoch: [11]  [70/97]  eta: 0:00:24  lr: 0.001951  loss: 4.8976 (4.9136)  time: 0.8012  data: 0.0005  max mem: 46135
# Epoch: [11]  [80/97]  eta: 0:00:15  lr: 0.001951  loss: 4.9353 (4.9136)  time: 0.8024  data: 0.0012  max mem: 46135
# Epoch: [11]  [90/97]  eta: 0:00:06  lr: 0.001951  loss: 4.9353 (4.9114)  time: 0.8003  data: 0.0011  max mem: 46135
# Epoch: [11]  [96/97]  eta: 0:00:00  lr: 0.001951  loss: 4.8864 (4.9061)  time: 0.7985  data: 0.0009  max mem: 46135
# Epoch: [11] Total time: 0:01:25 (0.8783 s / it)
# Averaged stats: lr: 0.001951  loss: 4.8864 (4.9061)
# Test:  [0/7]  eta: 0:00:42  loss: 5.4507 (5.4507)  acc1: 2.7344 (2.7344)  acc5: 12.3698 (12.3698)  time: 6.1197  data: 5.8896  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.3442 (5.3117)  acc1: 4.8177 (5.0000)  acc5: 15.9505 (16.7100)  time: 1.1655  data: 0.9676  max mem: 46135
# Test: Total time: 0:00:08 (1.1761 s / it)
# * Acc@1 5.000 Acc@5 16.710 loss 5.312
# Accuracy of the network on the 10000 test images: 5.0%
# Max accuracy: 5.47%
# Epoch: [12]  [ 0/97]  eta: 0:16:44  lr: 0.001941  loss: 4.8730 (4.8730)  time: 10.3560  data: 9.5264  max mem: 46135
# Epoch: [12]  [10/97]  eta: 0:02:25  lr: 0.001941  loss: 4.9351 (4.9333)  time: 1.6726  data: 0.8665  max mem: 46135
# Epoch: [12]  [20/97]  eta: 0:01:36  lr: 0.001941  loss: 4.9591 (4.9448)  time: 0.8038  data: 0.0005  max mem: 46135
# Epoch: [12]  [30/97]  eta: 0:01:14  lr: 0.001941  loss: 4.9369 (4.9310)  time: 0.8027  data: 0.0005  max mem: 46135
# Epoch: [12]  [40/97]  eta: 0:00:59  lr: 0.001941  loss: 4.9256 (4.9274)  time: 0.8020  data: 0.0006  max mem: 46135
# Epoch: [12]  [50/97]  eta: 0:00:46  lr: 0.001941  loss: 4.9323 (4.9210)  time: 0.8025  data: 0.0006  max mem: 46135
# Epoch: [12]  [60/97]  eta: 0:00:35  lr: 0.001941  loss: 4.9185 (4.9127)  time: 0.8016  data: 0.0005  max mem: 46135
# Epoch: [12]  [70/97]  eta: 0:00:25  lr: 0.001941  loss: 4.8866 (4.9074)  time: 0.8003  data: 0.0005  max mem: 46135
# Epoch: [12]  [80/97]  eta: 0:00:15  lr: 0.001941  loss: 4.9167 (4.9264)  time: 0.8015  data: 0.0013  max mem: 46135
# Epoch: [12]  [90/97]  eta: 0:00:06  lr: 0.001941  loss: 5.0044 (4.9361)  time: 0.7994  data: 0.0011  max mem: 46135
# Epoch: [12]  [96/97]  eta: 0:00:00  lr: 0.001941  loss: 5.0129 (4.9421)  time: 0.7969  data: 0.0010  max mem: 46135
# Epoch: [12] Total time: 0:01:27 (0.9030 s / it)
# Averaged stats: lr: 0.001941  loss: 5.0129 (4.9421)
# Test:  [0/7]  eta: 0:00:47  loss: 5.6502 (5.6502)  acc1: 0.0000 (0.0000)  acc5: 3.0599 (3.0599)  time: 6.7433  data: 6.5235  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.6084 (5.5084)  acc1: 0.7161 (1.5200)  acc5: 6.4453 (6.6000)  time: 1.1273  data: 0.9321  max mem: 46135
# Test: Total time: 0:00:07 (1.1395 s / it)
# * Acc@1 1.520 Acc@5 6.600 loss 5.508
# Accuracy of the network on the 10000 test images: 1.5%
# Max accuracy: 5.47%
# Epoch: [13]  [ 0/97]  eta: 0:14:12  lr: 0.001930  loss: 4.9784 (4.9784)  time: 8.7840  data: 7.9579  max mem: 46135
# Epoch: [13]  [10/97]  eta: 0:02:14  lr: 0.001930  loss: 5.0130 (5.0027)  time: 1.5490  data: 0.7426  max mem: 46135
# Epoch: [13]  [20/97]  eta: 0:01:31  lr: 0.001930  loss: 5.0078 (4.9976)  time: 0.8141  data: 0.0109  max mem: 46135
# Epoch: [13]  [30/97]  eta: 0:01:11  lr: 0.001930  loss: 4.9918 (4.9913)  time: 0.8031  data: 0.0007  max mem: 46135
# Epoch: [13]  [40/97]  eta: 0:00:57  lr: 0.001930  loss: 4.9703 (4.9804)  time: 0.8039  data: 0.0006  max mem: 46135
# Epoch: [13]  [50/97]  eta: 0:00:45  lr: 0.001930  loss: 4.9473 (4.9668)  time: 0.8024  data: 0.0006  max mem: 46135
# Epoch: [13]  [60/97]  eta: 0:00:34  lr: 0.001930  loss: 4.8950 (4.9542)  time: 0.8014  data: 0.0005  max mem: 46135
# Epoch: [13]  [70/97]  eta: 0:00:24  lr: 0.001930  loss: 4.9277 (4.9533)  time: 0.8015  data: 0.0005  max mem: 46135
# Epoch: [13]  [80/97]  eta: 0:00:15  lr: 0.001930  loss: 4.9785 (4.9516)  time: 0.8002  data: 0.0010  max mem: 46135
# Epoch: [13]  [90/97]  eta: 0:00:06  lr: 0.001930  loss: 4.9544 (4.9516)  time: 0.7984  data: 0.0009  max mem: 46135
# Epoch: [13]  [96/97]  eta: 0:00:00  lr: 0.001930  loss: 4.9637 (4.9515)  time: 0.7982  data: 0.0008  max mem: 46135
# Epoch: [13] Total time: 0:01:26 (0.8890 s / it)
# Averaged stats: lr: 0.001930  loss: 4.9637 (4.9515)
# Test:  [0/7]  eta: 0:00:39  loss: 5.5420 (5.5420)  acc1: 1.0417 (1.0417)  acc5: 8.5938 (8.5938)  time: 5.6899  data: 5.4698  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.4602 (5.3846)  acc1: 2.9297 (3.1600)  acc5: 11.0677 (12.4300)  time: 1.1206  data: 0.9242  max mem: 46135
# Test: Total time: 0:00:08 (1.1441 s / it)
# * Acc@1 3.160 Acc@5 12.430 loss 5.385
# Accuracy of the network on the 10000 test images: 3.2%
# Max accuracy: 5.47%
# Epoch: [14]  [ 0/97]  eta: 0:16:37  lr: 0.001918  loss: 4.8960 (4.8960)  time: 10.2809  data: 9.4547  max mem: 46135
# Epoch: [14]  [10/97]  eta: 0:02:24  lr: 0.001918  loss: 4.9625 (4.9479)  time: 1.6649  data: 0.8600  max mem: 46135
# Epoch: [14]  [20/97]  eta: 0:01:36  lr: 0.001918  loss: 4.9515 (4.9393)  time: 0.8035  data: 0.0005  max mem: 46135
# Epoch: [14]  [30/97]  eta: 0:01:14  lr: 0.001918  loss: 4.9478 (4.9309)  time: 0.8033  data: 0.0005  max mem: 46135
# Epoch: [14]  [40/97]  eta: 0:00:58  lr: 0.001918  loss: 4.8878 (4.9154)  time: 0.8028  data: 0.0005  max mem: 46135
# Epoch: [14]  [50/97]  eta: 0:00:46  lr: 0.001918  loss: 4.8882 (4.9165)  time: 0.8028  data: 0.0005  max mem: 46135
# Epoch: [14]  [60/97]  eta: 0:00:35  lr: 0.001918  loss: 4.9095 (4.9134)  time: 0.8028  data: 0.0006  max mem: 46135
# Epoch: [14]  [70/97]  eta: 0:00:25  lr: 0.001918  loss: 4.8847 (4.9109)  time: 0.8040  data: 0.0006  max mem: 46135
# Epoch: [14]  [80/97]  eta: 0:00:15  lr: 0.001918  loss: 4.9229 (4.9091)  time: 0.8037  data: 0.0012  max mem: 46135
# Epoch: [14]  [90/97]  eta: 0:00:06  lr: 0.001918  loss: 4.9226 (4.9064)  time: 0.8002  data: 0.0010  max mem: 46135
# Epoch: [14]  [96/97]  eta: 0:00:00  lr: 0.001918  loss: 4.8603 (4.9035)  time: 0.7995  data: 0.0009  max mem: 46135
# Epoch: [14] Total time: 0:01:27 (0.9027 s / it)
# Averaged stats: lr: 0.001918  loss: 4.8603 (4.9035)
# Test:  [0/7]  eta: 0:00:47  loss: 5.4284 (5.4284)  acc1: 2.6693 (2.6693)  acc5: 11.1328 (11.1328)  time: 6.8118  data: 6.5819  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.3401 (5.2960)  acc1: 4.8828 (5.0800)  acc5: 15.1693 (16.3200)  time: 1.1589  data: 0.9608  max mem: 46135
# Test: Total time: 0:00:08 (1.1720 s / it)
# * Acc@1 5.080 Acc@5 16.320 loss 5.296
# Accuracy of the network on the 10000 test images: 5.1%
# Max accuracy: 5.47%
# Epoch: [15]  [ 0/97]  eta: 0:15:47  lr: 0.001905  loss: 4.9783 (4.9783)  time: 9.7630  data: 8.9587  max mem: 46135
# Epoch: [15]  [10/97]  eta: 0:02:20  lr: 0.001905  loss: 4.9392 (4.8950)  time: 1.6181  data: 0.8149  max mem: 46135
# Epoch: [15]  [20/97]  eta: 0:01:34  lr: 0.001905  loss: 4.9382 (4.8835)  time: 0.8034  data: 0.0005  max mem: 46135
# Epoch: [15]  [30/97]  eta: 0:01:13  lr: 0.001905  loss: 4.8522 (4.8580)  time: 0.8043  data: 0.0007  max mem: 46135
# Epoch: [15]  [40/97]  eta: 0:00:58  lr: 0.001905  loss: 4.8006 (4.8482)  time: 0.8048  data: 0.0007  max mem: 46135
# Epoch: [15]  [50/97]  eta: 0:00:46  lr: 0.001905  loss: 4.8486 (4.8573)  time: 0.8030  data: 0.0005  max mem: 46135
# Epoch: [15]  [60/97]  eta: 0:00:35  lr: 0.001905  loss: 4.8995 (4.8615)  time: 0.8019  data: 0.0006  max mem: 46135
# Epoch: [15]  [70/97]  eta: 0:00:25  lr: 0.001905  loss: 4.9107 (4.8687)  time: 0.8015  data: 0.0005  max mem: 46135
# Epoch: [15]  [80/97]  eta: 0:00:15  lr: 0.001905  loss: 4.8942 (4.8676)  time: 0.8022  data: 0.0011  max mem: 46135
# Epoch: [15]  [90/97]  eta: 0:00:06  lr: 0.001905  loss: 4.8716 (4.8643)  time: 0.8008  data: 0.0010  max mem: 46135
# Epoch: [15]  [96/97]  eta: 0:00:00  lr: 0.001905  loss: 4.8716 (4.8625)  time: 0.7987  data: 0.0009  max mem: 46135
# Epoch: [15] Total time: 0:01:27 (0.8980 s / it)
# Averaged stats: lr: 0.001905  loss: 4.8716 (4.8625)
# Test:  [0/7]  eta: 0:00:50  loss: 5.4007 (5.4007)  acc1: 2.2135 (2.2135)  acc5: 12.3047 (12.3047)  time: 7.1449  data: 6.9268  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.3173 (5.2728)  acc1: 4.6875 (5.0700)  acc5: 15.7552 (16.9700)  time: 1.1864  data: 0.9897  max mem: 46135
# Test: Total time: 0:00:08 (1.1971 s / it)
# * Acc@1 5.070 Acc@5 16.970 loss 5.273
# Accuracy of the network on the 10000 test images: 5.1%
# Max accuracy: 5.47%
# Epoch: [16]  [ 0/97]  eta: 0:15:54  lr: 0.001892  loss: 4.9554 (4.9554)  time: 9.8359  data: 9.0220  max mem: 46135
# Epoch: [16]  [10/97]  eta: 0:02:21  lr: 0.001892  loss: 4.8833 (4.8382)  time: 1.6242  data: 0.8207  max mem: 46135
# Epoch: [16]  [20/97]  eta: 0:01:34  lr: 0.001892  loss: 4.8014 (4.8390)  time: 0.8036  data: 0.0005  max mem: 46135
# Epoch: [16]  [30/97]  eta: 0:01:13  lr: 0.001892  loss: 4.8577 (4.8357)  time: 0.8042  data: 0.0005  max mem: 46135
# Epoch: [16]  [40/97]  eta: 0:00:58  lr: 0.001892  loss: 4.8674 (4.8475)  time: 0.8038  data: 0.0008  max mem: 46135
# Epoch: [16]  [50/97]  eta: 0:00:46  lr: 0.001892  loss: 4.9109 (4.8612)  time: 0.8170  data: 0.0008  max mem: 46135
# Epoch: [16]  [60/97]  eta: 0:00:35  lr: 0.001892  loss: 4.8929 (4.8616)  time: 0.8168  data: 0.0006  max mem: 46135
# Epoch: [16]  [70/97]  eta: 0:00:25  lr: 0.001892  loss: 4.8645 (4.8603)  time: 0.8029  data: 0.0006  max mem: 46135
# Epoch: [16]  [80/97]  eta: 0:00:15  lr: 0.001892  loss: 4.8645 (4.8655)  time: 0.8027  data: 0.0010  max mem: 46135
# Epoch: [16]  [90/97]  eta: 0:00:06  lr: 0.001892  loss: 4.8849 (4.8613)  time: 0.8003  data: 0.0008  max mem: 46135
# Epoch: [16]  [96/97]  eta: 0:00:00  lr: 0.001892  loss: 4.8379 (4.8532)  time: 0.7986  data: 0.0006  max mem: 46135
# Epoch: [16] Total time: 0:01:27 (0.9011 s / it)
# Averaged stats: lr: 0.001892  loss: 4.8379 (4.8532)
# Test:  [0/7]  eta: 0:00:51  loss: 5.3537 (5.3537)  acc1: 3.5807 (3.5807)  acc5: 14.1927 (14.1927)  time: 7.3173  data: 7.0971  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2979 (5.2155)  acc1: 5.3385 (6.2900)  acc5: 19.7917 (20.7200)  time: 1.2109  data: 1.0141  max mem: 46135
# Test: Total time: 0:00:08 (1.2223 s / it)
# * Acc@1 6.290 Acc@5 20.720 loss 5.215
# Accuracy of the network on the 10000 test images: 6.3%
# Max accuracy: 6.29%
# Epoch: [17]  [ 0/97]  eta: 0:16:39  lr: 0.001877  loss: 4.9554 (4.9554)  time: 10.3083  data: 9.5017  max mem: 46135
# Epoch: [17]  [10/97]  eta: 0:02:25  lr: 0.001877  loss: 4.8098 (4.7999)  time: 1.6673  data: 0.8643  max mem: 46135
# Epoch: [17]  [20/97]  eta: 0:01:36  lr: 0.001877  loss: 4.8098 (4.8074)  time: 0.8048  data: 0.0006  max mem: 46135
# Epoch: [17]  [30/97]  eta: 0:01:14  lr: 0.001877  loss: 4.8378 (4.8115)  time: 0.8055  data: 0.0006  max mem: 46135
# Epoch: [17]  [40/97]  eta: 0:00:59  lr: 0.001877  loss: 4.8893 (4.8218)  time: 0.8028  data: 0.0005  max mem: 46135
# Epoch: [17]  [50/97]  eta: 0:00:46  lr: 0.001877  loss: 4.9017 (4.8348)  time: 0.8010  data: 0.0005  max mem: 46135
# Epoch: [17]  [60/97]  eta: 0:00:35  lr: 0.001877  loss: 4.8538 (4.8361)  time: 0.8013  data: 0.0005  max mem: 46135
# Epoch: [17]  [70/97]  eta: 0:00:25  lr: 0.001877  loss: 4.8256 (4.8352)  time: 0.8015  data: 0.0005  max mem: 46135
# Epoch: [17]  [80/97]  eta: 0:00:15  lr: 0.001877  loss: 4.8621 (4.8392)  time: 0.8009  data: 0.0008  max mem: 46135
# Epoch: [17]  [90/97]  eta: 0:00:06  lr: 0.001877  loss: 4.8754 (4.8401)  time: 0.7990  data: 0.0007  max mem: 46135
# Epoch: [17]  [96/97]  eta: 0:00:00  lr: 0.001877  loss: 4.8754 (4.8397)  time: 0.7979  data: 0.0006  max mem: 46135
# Epoch: [17] Total time: 0:01:27 (0.9033 s / it)
# Averaged stats: lr: 0.001877  loss: 4.8754 (4.8397)
# Test:  [0/7]  eta: 0:00:44  loss: 5.3951 (5.3951)  acc1: 1.4974 (1.4974)  acc5: 10.6771 (10.6771)  time: 6.3976  data: 6.1773  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.3276 (5.2560)  acc1: 5.0130 (5.0600)  acc5: 14.9089 (16.8200)  time: 1.1516  data: 0.9550  max mem: 46135
# Test: Total time: 0:00:08 (1.1732 s / it)
# * Acc@1 5.060 Acc@5 16.820 loss 5.256
# Accuracy of the network on the 10000 test images: 5.1%
# Max accuracy: 6.29%
# Epoch: [18]  [ 0/97]  eta: 0:16:31  lr: 0.001861  loss: 4.7746 (4.7746)  time: 10.2261  data: 9.4073  max mem: 46135
# Epoch: [18]  [10/97]  eta: 0:02:24  lr: 0.001861  loss: 4.7746 (4.7992)  time: 1.6584  data: 0.8559  max mem: 46135
# Epoch: [18]  [20/97]  eta: 0:01:36  lr: 0.001861  loss: 4.9007 (4.8372)  time: 0.8026  data: 0.0007  max mem: 46135
# Epoch: [18]  [30/97]  eta: 0:01:14  lr: 0.001861  loss: 4.9029 (4.8477)  time: 0.8025  data: 0.0007  max mem: 46135
# Epoch: [18]  [40/97]  eta: 0:00:58  lr: 0.001861  loss: 4.8715 (4.8373)  time: 0.7997  data: 0.0007  max mem: 46135
# Epoch: [18]  [50/97]  eta: 0:00:46  lr: 0.001861  loss: 4.8605 (4.8457)  time: 0.8004  data: 0.0005  max mem: 46135
# Epoch: [18]  [60/97]  eta: 0:00:35  lr: 0.001861  loss: 4.8605 (4.8419)  time: 0.8023  data: 0.0006  max mem: 46135
# Epoch: [18]  [70/97]  eta: 0:00:25  lr: 0.001861  loss: 4.8466 (4.8386)  time: 0.8028  data: 0.0006  max mem: 46135
# Epoch: [18]  [80/97]  eta: 0:00:15  lr: 0.001861  loss: 4.8497 (4.8407)  time: 0.8025  data: 0.0012  max mem: 46135
# Epoch: [18]  [90/97]  eta: 0:00:06  lr: 0.001861  loss: 4.8958 (4.8447)  time: 0.7995  data: 0.0010  max mem: 46135
# Epoch: [18]  [96/97]  eta: 0:00:00  lr: 0.001861  loss: 4.8701 (4.8397)  time: 0.7984  data: 0.0009  max mem: 46135
# Epoch: [18] Total time: 0:01:27 (0.9013 s / it)
# Averaged stats: lr: 0.001861  loss: 4.8701 (4.8397)
# Test:  [0/7]  eta: 0:00:42  loss: 5.3894 (5.3894)  acc1: 2.9297 (2.9297)  acc5: 12.6302 (12.6302)  time: 6.0412  data: 5.8111  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2892 (5.2167)  acc1: 6.1849 (6.3400)  acc5: 19.1406 (20.0800)  time: 1.1520  data: 0.9541  max mem: 46135
# Test: Total time: 0:00:08 (1.1628 s / it)
# * Acc@1 6.340 Acc@5 20.080 loss 5.217
# Accuracy of the network on the 10000 test images: 6.3%
# Max accuracy: 6.34%
# Epoch: [19]  [ 0/97]  eta: 0:15:28  lr: 0.001845  loss: 4.9233 (4.9233)  time: 9.5725  data: 8.7563  max mem: 46135
# Epoch: [19]  [10/97]  eta: 0:02:19  lr: 0.001845  loss: 4.8211 (4.7692)  time: 1.6027  data: 0.7965  max mem: 46135
# Epoch: [19]  [20/97]  eta: 0:01:34  lr: 0.001845  loss: 4.8135 (4.7854)  time: 0.8053  data: 0.0005  max mem: 46135
# Epoch: [19]  [30/97]  eta: 0:01:12  lr: 0.001845  loss: 4.8462 (4.7942)  time: 0.8038  data: 0.0006  max mem: 46135
# Epoch: [19]  [40/97]  eta: 0:00:58  lr: 0.001845  loss: 4.8568 (4.8072)  time: 0.8037  data: 0.0006  max mem: 46135
# Epoch: [19]  [50/97]  eta: 0:00:45  lr: 0.001845  loss: 4.8535 (4.7991)  time: 0.8030  data: 0.0006  max mem: 46135
# Epoch: [19]  [60/97]  eta: 0:00:35  lr: 0.001845  loss: 4.7934 (4.8017)  time: 0.8017  data: 0.0006  max mem: 46135
# Epoch: [19]  [70/97]  eta: 0:00:25  lr: 0.001845  loss: 4.8217 (4.8022)  time: 0.8034  data: 0.0006  max mem: 46135
# Epoch: [19]  [80/97]  eta: 0:00:15  lr: 0.001845  loss: 4.7481 (4.7923)  time: 0.8025  data: 0.0012  max mem: 46135
# Epoch: [19]  [90/97]  eta: 0:00:06  lr: 0.001845  loss: 4.7201 (4.7894)  time: 0.7993  data: 0.0010  max mem: 46135
# Epoch: [19]  [96/97]  eta: 0:00:00  lr: 0.001845  loss: 4.7481 (4.7878)  time: 0.7987  data: 0.0009  max mem: 46135
# Epoch: [19] Total time: 0:01:26 (0.8962 s / it)
# Averaged stats: lr: 0.001845  loss: 4.7481 (4.7878)
# Test:  [0/7]  eta: 0:00:50  loss: 5.2675 (5.2675)  acc1: 4.7526 (4.7526)  acc5: 16.4062 (16.4062)  time: 7.2692  data: 7.0407  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2125 (5.1549)  acc1: 6.9661 (6.7500)  acc5: 20.2474 (21.5500)  time: 1.2037  data: 1.0060  max mem: 46135
# Test: Total time: 0:00:08 (1.2152 s / it)
# * Acc@1 6.750 Acc@5 21.550 loss 5.155
# Accuracy of the network on the 10000 test images: 6.8%
# Max accuracy: 6.75%
# Epoch: [20]  [ 0/97]  eta: 0:13:49  lr: 0.001828  loss: 4.8579 (4.8579)  time: 8.5468  data: 7.7127  max mem: 46135
# Epoch: [20]  [10/97]  eta: 0:02:11  lr: 0.001828  loss: 4.8169 (4.7869)  time: 1.5156  data: 0.7071  max mem: 46135
# Epoch: [20]  [20/97]  eta: 0:01:30  lr: 0.001828  loss: 4.8008 (4.7823)  time: 0.8084  data: 0.0037  max mem: 46135
# Epoch: [20]  [30/97]  eta: 0:01:10  lr: 0.001828  loss: 4.7679 (4.7689)  time: 0.8036  data: 0.0007  max mem: 46135
# Epoch: [20]  [40/97]  eta: 0:00:56  lr: 0.001828  loss: 4.8192 (4.7779)  time: 0.8023  data: 0.0006  max mem: 46135
# Epoch: [20]  [50/97]  eta: 0:00:44  lr: 0.001828  loss: 4.8199 (4.7798)  time: 0.8025  data: 0.0006  max mem: 46135
# Epoch: [20]  [60/97]  eta: 0:00:34  lr: 0.001828  loss: 4.8193 (4.7804)  time: 0.8030  data: 0.0006  max mem: 46135
# Epoch: [20]  [70/97]  eta: 0:00:24  lr: 0.001828  loss: 4.8545 (4.7918)  time: 0.8021  data: 0.0006  max mem: 46135
# Epoch: [20]  [80/97]  eta: 0:00:15  lr: 0.001828  loss: 4.8557 (4.7919)  time: 0.8009  data: 0.0012  max mem: 46135
# Epoch: [20]  [90/97]  eta: 0:00:06  lr: 0.001828  loss: 4.8674 (4.7989)  time: 0.7983  data: 0.0010  max mem: 46135
# Epoch: [20]  [96/97]  eta: 0:00:00  lr: 0.001828  loss: 4.8985 (4.8017)  time: 0.7978  data: 0.0009  max mem: 46135
# Epoch: [20] Total time: 0:01:25 (0.8856 s / it)
# Averaged stats: lr: 0.001828  loss: 4.8985 (4.8017)
# Test:  [0/7]  eta: 0:00:40  loss: 5.3747 (5.3747)  acc1: 2.2135 (2.2135)  acc5: 10.4818 (10.4818)  time: 5.8364  data: 5.6202  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2752 (5.2119)  acc1: 5.5339 (5.9500)  acc5: 17.3828 (18.6300)  time: 1.1736  data: 0.9780  max mem: 46135
# Test: Total time: 0:00:08 (1.1845 s / it)
# * Acc@1 5.950 Acc@5 18.630 loss 5.212
# Accuracy of the network on the 10000 test images: 6.0%
# Max accuracy: 6.75%
# Epoch: [21]  [ 0/97]  eta: 0:16:05  lr: 0.001810  loss: 4.7659 (4.7659)  time: 9.9505  data: 9.1346  max mem: 46135
# Epoch: [21]  [10/97]  eta: 0:02:22  lr: 0.001810  loss: 4.8046 (4.7927)  time: 1.6355  data: 0.8309  max mem: 46135
# Epoch: [21]  [20/97]  eta: 0:01:35  lr: 0.001810  loss: 4.7770 (4.7661)  time: 0.8044  data: 0.0005  max mem: 46135
# Epoch: [21]  [30/97]  eta: 0:01:13  lr: 0.001810  loss: 4.7568 (4.7699)  time: 0.8042  data: 0.0006  max mem: 46135
# Epoch: [21]  [40/97]  eta: 0:00:58  lr: 0.001810  loss: 4.8210 (4.7865)  time: 0.8032  data: 0.0007  max mem: 46135
# Epoch: [21]  [50/97]  eta: 0:00:46  lr: 0.001810  loss: 4.8312 (4.7903)  time: 0.8040  data: 0.0007  max mem: 46135
# Epoch: [21]  [60/97]  eta: 0:00:35  lr: 0.001810  loss: 4.8417 (4.7928)  time: 0.8026  data: 0.0006  max mem: 46135
# Epoch: [21]  [70/97]  eta: 0:00:25  lr: 0.001810  loss: 4.8417 (4.7938)  time: 0.8029  data: 0.0006  max mem: 46135
# Epoch: [21]  [80/97]  eta: 0:00:15  lr: 0.001810  loss: 4.8599 (4.7980)  time: 0.8040  data: 0.0009  max mem: 46135
# Epoch: [21]  [90/97]  eta: 0:00:06  lr: 0.001810  loss: 4.8069 (4.7964)  time: 0.7994  data: 0.0007  max mem: 46135
# Epoch: [21]  [96/97]  eta: 0:00:00  lr: 0.001810  loss: 4.8344 (4.7995)  time: 0.7981  data: 0.0006  max mem: 46135
# Epoch: [21] Total time: 0:01:27 (0.9000 s / it)
# Averaged stats: lr: 0.001810  loss: 4.8344 (4.7995)
# Test:  [0/7]  eta: 0:00:47  loss: 5.3728 (5.3728)  acc1: 2.7344 (2.7344)  acc5: 12.1094 (12.1094)  time: 6.7601  data: 6.5442  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2088 (5.1991)  acc1: 6.7708 (6.0600)  acc5: 19.1406 (19.6400)  time: 1.1529  data: 0.9574  max mem: 46135
# Test: Total time: 0:00:08 (1.1636 s / it)
# * Acc@1 6.060 Acc@5 19.640 loss 5.199
# Accuracy of the network on the 10000 test images: 6.1%
# Max accuracy: 6.75%
# Epoch: [22]  [ 0/97]  eta: 0:15:48  lr: 0.001791  loss: 4.9231 (4.9231)  time: 9.7753  data: 8.9487  max mem: 46135
# Epoch: [22]  [10/97]  eta: 0:02:20  lr: 0.001791  loss: 4.8579 (4.8070)  time: 1.6177  data: 0.8139  max mem: 46135
# Epoch: [22]  [20/97]  eta: 0:01:34  lr: 0.001791  loss: 4.8461 (4.8113)  time: 0.8020  data: 0.0005  max mem: 46135
# Epoch: [22]  [30/97]  eta: 0:01:13  lr: 0.001791  loss: 4.8324 (4.8073)  time: 0.8030  data: 0.0005  max mem: 46135
# Epoch: [22]  [40/97]  eta: 0:00:58  lr: 0.001791  loss: 4.7845 (4.7945)  time: 0.8025  data: 0.0006  max mem: 46135
# Epoch: [22]  [50/97]  eta: 0:00:45  lr: 0.001791  loss: 4.7845 (4.7982)  time: 0.8025  data: 0.0006  max mem: 46135
# Epoch: [22]  [60/97]  eta: 0:00:35  lr: 0.001791  loss: 4.8818 (4.8090)  time: 0.8014  data: 0.0005  max mem: 46135
# Epoch: [22]  [70/97]  eta: 0:00:25  lr: 0.001791  loss: 4.8285 (4.7980)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [22]  [80/97]  eta: 0:00:15  lr: 0.001791  loss: 4.7880 (4.7976)  time: 0.8019  data: 0.0012  max mem: 46135
# Epoch: [22]  [90/97]  eta: 0:00:06  lr: 0.001791  loss: 4.7697 (4.7919)  time: 0.7993  data: 0.0011  max mem: 46135
# Epoch: [22]  [96/97]  eta: 0:00:00  lr: 0.001791  loss: 4.7314 (4.7897)  time: 0.7981  data: 0.0009  max mem: 46135
# Epoch: [22] Total time: 0:01:26 (0.8965 s / it)
# Averaged stats: lr: 0.001791  loss: 4.7314 (4.7897)
# Test:  [0/7]  eta: 0:00:42  loss: 5.3545 (5.3545)  acc1: 2.8646 (2.8646)  acc5: 14.7786 (14.7786)  time: 6.0778  data: 5.8486  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.1926 (5.1480)  acc1: 7.6823 (7.4100)  acc5: 22.7214 (23.8400)  time: 1.0698  data: 0.8725  max mem: 46135
# Test: Total time: 0:00:07 (1.0801 s / it)
# * Acc@1 7.410 Acc@5 23.840 loss 5.148
# Accuracy of the network on the 10000 test images: 7.4%
# Max accuracy: 7.41%
# Epoch: [23]  [ 0/97]  eta: 0:16:42  lr: 0.001772  loss: 4.5573 (4.5573)  time: 10.3360  data: 9.5034  max mem: 46135
# Epoch: [23]  [10/97]  eta: 0:02:25  lr: 0.001772  loss: 4.7059 (4.7500)  time: 1.6702  data: 0.8646  max mem: 46135
# Epoch: [23]  [20/97]  eta: 0:01:36  lr: 0.001772  loss: 4.7461 (4.7527)  time: 0.8040  data: 0.0007  max mem: 46135
# Epoch: [23]  [30/97]  eta: 0:01:14  lr: 0.001772  loss: 4.7461 (4.7543)  time: 0.8038  data: 0.0006  max mem: 46135
# Epoch: [23]  [40/97]  eta: 0:00:58  lr: 0.001772  loss: 4.7846 (4.7669)  time: 0.8008  data: 0.0005  max mem: 46135
# Epoch: [23]  [50/97]  eta: 0:00:46  lr: 0.001772  loss: 4.8367 (4.7755)  time: 0.7986  data: 0.0005  max mem: 46135
# Epoch: [23]  [60/97]  eta: 0:00:35  lr: 0.001772  loss: 4.8197 (4.7704)  time: 0.7993  data: 0.0006  max mem: 46135
# Epoch: [23]  [70/97]  eta: 0:00:25  lr: 0.001772  loss: 4.7698 (4.7637)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [23]  [80/97]  eta: 0:00:15  lr: 0.001772  loss: 4.8118 (4.7645)  time: 0.8004  data: 0.0008  max mem: 46135
# Epoch: [23]  [90/97]  eta: 0:00:06  lr: 0.001772  loss: 4.8392 (4.7714)  time: 0.7981  data: 0.0007  max mem: 46135
# Epoch: [23]  [96/97]  eta: 0:00:00  lr: 0.001772  loss: 4.8436 (4.7770)  time: 0.7975  data: 0.0006  max mem: 46135
# Epoch: [23] Total time: 0:01:27 (0.9023 s / it)
# Averaged stats: lr: 0.001772  loss: 4.8436 (4.7770)
# Test:  [0/7]  eta: 0:00:44  loss: 5.3469 (5.3469)  acc1: 3.1250 (3.1250)  acc5: 13.1510 (13.1510)  time: 6.4066  data: 6.1898  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.2807 (5.2049)  acc1: 6.0547 (6.5600)  acc5: 19.7917 (19.9600)  time: 1.0798  data: 0.8845  max mem: 46135
# Test: Total time: 0:00:07 (1.0909 s / it)
# * Acc@1 6.560 Acc@5 19.960 loss 5.205
# Accuracy of the network on the 10000 test images: 6.6%
# Max accuracy: 7.41%
# Epoch: [24]  [ 0/97]  eta: 0:16:05  lr: 0.001751  loss: 4.6927 (4.6927)  time: 9.9488  data: 9.1249  max mem: 46135
# Epoch: [24]  [10/97]  eta: 0:02:22  lr: 0.001751  loss: 4.8109 (4.7838)  time: 1.6350  data: 0.8301  max mem: 46135
# Epoch: [24]  [20/97]  eta: 0:01:35  lr: 0.001751  loss: 4.8109 (4.7868)  time: 0.8034  data: 0.0006  max mem: 46135
# Epoch: [24]  [30/97]  eta: 0:01:13  lr: 0.001751  loss: 4.7786 (4.7739)  time: 0.8023  data: 0.0006  max mem: 46135
# Epoch: [24]  [40/97]  eta: 0:00:58  lr: 0.001751  loss: 4.7291 (4.7538)  time: 0.8027  data: 0.0005  max mem: 46135
# Epoch: [24]  [50/97]  eta: 0:00:46  lr: 0.001751  loss: 4.7545 (4.7549)  time: 0.8025  data: 0.0006  max mem: 46135
# Epoch: [24]  [60/97]  eta: 0:00:35  lr: 0.001751  loss: 4.8208 (4.7571)  time: 0.8004  data: 0.0005  max mem: 46135
# Epoch: [24]  [70/97]  eta: 0:00:25  lr: 0.001751  loss: 4.8280 (4.7528)  time: 0.7990  data: 0.0005  max mem: 46135
# Epoch: [24]  [80/97]  eta: 0:00:15  lr: 0.001751  loss: 4.8450 (4.7663)  time: 0.7998  data: 0.0009  max mem: 46135
# Epoch: [24]  [90/97]  eta: 0:00:06  lr: 0.001751  loss: 4.7735 (4.7572)  time: 0.7992  data: 0.0008  max mem: 46135
# Epoch: [24]  [96/97]  eta: 0:00:00  lr: 0.001751  loss: 4.7599 (4.7599)  time: 0.7976  data: 0.0007  max mem: 46135
# Epoch: [24] Total time: 0:01:27 (0.8974 s / it)
# Averaged stats: lr: 0.001751  loss: 4.7599 (4.7599)
# Test:  [0/7]  eta: 0:00:45  loss: 5.2423 (5.2423)  acc1: 3.7760 (3.7760)  acc5: 15.8854 (15.8854)  time: 6.4587  data: 6.2391  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 5.1994 (5.1165)  acc1: 6.3151 (7.0300)  acc5: 20.7682 (23.2700)  time: 1.1301  data: 0.9344  max mem: 46135
# Test: Total time: 0:00:08 (1.1515 s / it)
# * Acc@1 7.030 Acc@5 23.270 loss 5.117
# Accuracy of the network on the 10000 test images: 7.0%
# Max accuracy: 7.41%
# Epoch: [25]  [ 0/97]  eta: 0:14:36  lr: 0.001730  loss: 4.5081 (4.5081)  time: 9.0390  data: 8.1748  max mem: 46135
# Epoch: [25]  [10/97]  eta: 0:02:15  lr: 0.001730  loss: 4.8097 (4.7772)  time: 1.5544  data: 0.7441  max mem: 46135
# Epoch: [25]  [20/97]  eta: 0:01:32  lr: 0.001730  loss: 4.8097 (4.7744)  time: 0.8041  data: 0.0010  max mem: 46135
# Epoch: [25]  [30/97]  eta: 0:01:11  lr: 0.001730  loss: 4.8238 (4.7933)  time: 0.8032  data: 0.0008  max mem: 46135
# Epoch: [25]  [40/97]  eta: 0:00:57  lr: 0.001730  loss: 4.8008 (4.7543)  time: 0.8030  data: 0.0006  max mem: 46135
# ...
# Epoch: [91]  [40/97]  eta: 0:00:57  lr: 0.000059  loss: 4.2600 (4.3451)  time: 0.7988  data: 0.0006  max mem: 46135
# Epoch: [91]  [50/97]  eta: 0:00:45  lr: 0.000059  loss: 4.5202 (4.3420)  time: 0.7974  data: 0.0005  max mem: 46135
# Epoch: [91]  [60/97]  eta: 0:00:34  lr: 0.000059  loss: 4.5202 (4.3476)  time: 0.7963  data: 0.0005  max mem: 46135
# Epoch: [91]  [70/97]  eta: 0:00:24  lr: 0.000059  loss: 4.3222 (4.3317)  time: 0.7975  data: 0.0005  max mem: 46135
# Epoch: [91]  [80/97]  eta: 0:00:15  lr: 0.000059  loss: 4.2307 (4.3141)  time: 0.7971  data: 0.0011  max mem: 46135
# Epoch: [91]  [90/97]  eta: 0:00:06  lr: 0.000059  loss: 4.3764 (4.3233)  time: 0.7951  data: 0.0009  max mem: 46135
# Epoch: [91]  [96/97]  eta: 0:00:00  lr: 0.000059  loss: 4.3764 (4.3221)  time: 0.7951  data: 0.0008  max mem: 46135
# Epoch: [91] Total time: 0:01:26 (0.8925 s / it)
# Averaged stats: lr: 0.000059  loss: 4.3764 (4.3221)
# Test:  [0/7]  eta: 0:00:46  loss: 4.3746 (4.3746)  acc1: 23.4375 (23.4375)  acc5: 51.8880 (51.8880)  time: 6.6364  data: 6.4157  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3818 (4.3708)  acc1: 25.6510 (27.2700)  acc5: 51.8880 (54.6500)  time: 1.1097  data: 0.9167  max mem: 46135
# Test: Total time: 0:00:07 (1.1304 s / it)
# * Acc@1 27.270 Acc@5 54.650 loss 4.371
# Accuracy of the network on the 10000 test images: 27.3%
# Max accuracy: 27.31%
# Epoch: [92]  [ 0/97]  eta: 0:13:38  lr: 0.000050  loss: 4.4647 (4.4647)  time: 8.4337  data: 7.6229  max mem: 46135
# Epoch: [92]  [10/97]  eta: 0:02:11  lr: 0.000050  loss: 4.5338 (4.4402)  time: 1.5086  data: 0.7066  max mem: 46135
# Epoch: [92]  [20/97]  eta: 0:01:30  lr: 0.000050  loss: 4.3878 (4.3668)  time: 0.8081  data: 0.0077  max mem: 46135
# Epoch: [92]  [30/97]  eta: 0:01:10  lr: 0.000050  loss: 4.2503 (4.3283)  time: 0.8009  data: 0.0005  max mem: 46135
# Epoch: [92]  [40/97]  eta: 0:00:56  lr: 0.000050  loss: 4.5632 (4.3902)  time: 0.8007  data: 0.0008  max mem: 46135
# Epoch: [92]  [50/97]  eta: 0:00:44  lr: 0.000050  loss: 4.6025 (4.3931)  time: 0.7986  data: 0.0008  max mem: 46135
# Epoch: [92]  [60/97]  eta: 0:00:34  lr: 0.000050  loss: 4.3034 (4.3666)  time: 0.7965  data: 0.0005  max mem: 46135
# Epoch: [92]  [70/97]  eta: 0:00:24  lr: 0.000050  loss: 4.3034 (4.3620)  time: 0.7961  data: 0.0005  max mem: 46135
# Epoch: [92]  [80/97]  eta: 0:00:15  lr: 0.000050  loss: 4.2409 (4.3277)  time: 0.7986  data: 0.0012  max mem: 46135
# Epoch: [92]  [90/97]  eta: 0:00:06  lr: 0.000050  loss: 4.2046 (4.3193)  time: 0.7970  data: 0.0010  max mem: 46135
# Epoch: [92]  [96/97]  eta: 0:00:00  lr: 0.000050  loss: 4.3612 (4.3314)  time: 0.7949  data: 0.0009  max mem: 46135
# Epoch: [92] Total time: 0:01:25 (0.8812 s / it)
# Averaged stats: lr: 0.000050  loss: 4.3612 (4.3314)
# Test:  [0/7]  eta: 0:00:39  loss: 4.3858 (4.3858)  acc1: 23.5677 (23.5677)  acc5: 51.7578 (51.7578)  time: 5.6056  data: 5.3913  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3858 (4.3718)  acc1: 25.2604 (27.3700)  acc5: 51.7578 (54.4200)  time: 1.0826  data: 0.8905  max mem: 46135
# Test: Total time: 0:00:07 (1.0950 s / it)
# * Acc@1 27.370 Acc@5 54.420 loss 4.372
# Accuracy of the network on the 10000 test images: 27.4%
# Max accuracy: 27.37%
# Epoch: [93]  [ 0/97]  eta: 0:13:18  lr: 0.000041  loss: 4.0592 (4.0592)  time: 8.2336  data: 7.4042  max mem: 46135
# Epoch: [93]  [10/97]  eta: 0:02:08  lr: 0.000041  loss: 4.5063 (4.3210)  time: 1.4763  data: 0.6736  max mem: 46135
# Epoch: [93]  [20/97]  eta: 0:01:28  lr: 0.000041  loss: 4.2220 (4.2887)  time: 0.8003  data: 0.0007  max mem: 46135
# Epoch: [93]  [30/97]  eta: 0:01:09  lr: 0.000041  loss: 4.1398 (4.2468)  time: 0.8005  data: 0.0006  max mem: 46135
# Epoch: [93]  [40/97]  eta: 0:00:55  lr: 0.000041  loss: 4.1694 (4.2592)  time: 0.8004  data: 0.0005  max mem: 46135
# Epoch: [93]  [50/97]  eta: 0:00:44  lr: 0.000041  loss: 4.4173 (4.2655)  time: 0.7997  data: 0.0006  max mem: 46135
# Epoch: [93]  [60/97]  eta: 0:00:34  lr: 0.000041  loss: 4.3644 (4.2813)  time: 0.7994  data: 0.0005  max mem: 46135
# Epoch: [93]  [70/97]  eta: 0:00:24  lr: 0.000041  loss: 4.4340 (4.2957)  time: 0.7985  data: 0.0005  max mem: 46135
# Epoch: [93]  [80/97]  eta: 0:00:15  lr: 0.000041  loss: 4.3564 (4.2878)  time: 0.7984  data: 0.0008  max mem: 46135
# Epoch: [93]  [90/97]  eta: 0:00:06  lr: 0.000041  loss: 4.3504 (4.3033)  time: 0.7966  data: 0.0007  max mem: 46135
# Epoch: [93]  [96/97]  eta: 0:00:00  lr: 0.000041  loss: 4.3924 (4.2931)  time: 0.7949  data: 0.0006  max mem: 46135
# Epoch: [93] Total time: 0:01:25 (0.8787 s / it)
# Averaged stats: lr: 0.000041  loss: 4.3924 (4.2931)
# Test:  [0/7]  eta: 0:00:49  loss: 4.3568 (4.3568)  acc1: 23.8932 (23.8932)  acc5: 52.0833 (52.0833)  time: 7.1146  data: 6.8902  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3753 (4.3665)  acc1: 25.3906 (27.1400)  acc5: 52.0833 (54.5600)  time: 1.1781  data: 0.9845  max mem: 46135
# Test: Total time: 0:00:08 (1.1881 s / it)
# * Acc@1 27.140 Acc@5 54.560 loss 4.367
# Accuracy of the network on the 10000 test images: 27.1%
# Max accuracy: 27.37%
# Epoch: [94]  [ 0/97]  eta: 0:09:49  lr: 0.000034  loss: 4.0751 (4.0751)  time: 6.0766  data: 5.2610  max mem: 46135
# Epoch: [94]  [10/97]  eta: 0:02:14  lr: 0.000034  loss: 4.2560 (4.2774)  time: 1.5406  data: 0.7380  max mem: 46135
# Epoch: [94]  [20/97]  eta: 0:01:31  lr: 0.000034  loss: 4.3333 (4.2875)  time: 0.9434  data: 0.1434  max mem: 46135
# Epoch: [94]  [30/97]  eta: 0:01:11  lr: 0.000034  loss: 4.3333 (4.2889)  time: 0.7998  data: 0.0009  max mem: 46135
# Epoch: [94]  [40/97]  eta: 0:00:56  lr: 0.000034  loss: 4.1776 (4.2635)  time: 0.8006  data: 0.0009  max mem: 46135
# Epoch: [94]  [50/97]  eta: 0:00:45  lr: 0.000034  loss: 4.1776 (4.2877)  time: 0.8004  data: 0.0010  max mem: 46135
# Epoch: [94]  [60/97]  eta: 0:00:34  lr: 0.000034  loss: 4.3649 (4.2723)  time: 0.7980  data: 0.0007  max mem: 46135
# Epoch: [94]  [70/97]  eta: 0:00:24  lr: 0.000034  loss: 4.3012 (4.2759)  time: 0.7962  data: 0.0005  max mem: 46135
# Epoch: [94]  [80/97]  eta: 0:00:15  lr: 0.000034  loss: 4.3012 (4.2812)  time: 0.7957  data: 0.0008  max mem: 46135
# Epoch: [94]  [90/97]  eta: 0:00:06  lr: 0.000034  loss: 4.4437 (4.2874)  time: 0.7948  data: 0.0007  max mem: 46135
# Epoch: [94]  [96/97]  eta: 0:00:00  lr: 0.000034  loss: 4.5744 (4.2938)  time: 0.7947  data: 0.0006  max mem: 46135
# Epoch: [94] Total time: 0:01:25 (0.8849 s / it)
# Averaged stats: lr: 0.000034  loss: 4.5744 (4.2938)
# Test:  [0/7]  eta: 0:00:42  loss: 4.3523 (4.3523)  acc1: 23.6328 (23.6328)  acc5: 52.1484 (52.1484)  time: 6.0157  data: 5.8054  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3569 (4.3571)  acc1: 25.7812 (27.3500)  acc5: 52.1484 (54.6300)  time: 1.0667  data: 0.8752  max mem: 46135
# Test: Total time: 0:00:07 (1.0772 s / it)
# * Acc@1 27.350 Acc@5 54.630 loss 4.357
# Accuracy of the network on the 10000 test images: 27.4%
# Max accuracy: 27.37%
# Epoch: [95]  [ 0/97]  eta: 0:13:41  lr: 0.000028  loss: 4.6969 (4.6969)  time: 8.4740  data: 7.6519  max mem: 46135
# Epoch: [95]  [10/97]  eta: 0:02:10  lr: 0.000028  loss: 4.5363 (4.4422)  time: 1.4974  data: 0.6961  max mem: 46135
# Epoch: [95]  [20/97]  eta: 0:01:29  lr: 0.000028  loss: 4.3099 (4.3389)  time: 0.8007  data: 0.0005  max mem: 46135
# Epoch: [95]  [30/97]  eta: 0:01:10  lr: 0.000028  loss: 4.2685 (4.3199)  time: 0.8009  data: 0.0006  max mem: 46135
# Epoch: [95]  [40/97]  eta: 0:00:56  lr: 0.000028  loss: 4.3688 (4.3154)  time: 0.7996  data: 0.0007  max mem: 46135
# Epoch: [95]  [50/97]  eta: 0:00:44  lr: 0.000028  loss: 4.3536 (4.3218)  time: 0.7988  data: 0.0006  max mem: 46135
# Epoch: [95]  [60/97]  eta: 0:00:34  lr: 0.000028  loss: 4.3536 (4.3337)  time: 0.7991  data: 0.0005  max mem: 46135
# Epoch: [95]  [70/97]  eta: 0:00:24  lr: 0.000028  loss: 4.4480 (4.3305)  time: 0.7994  data: 0.0006  max mem: 46135
# Epoch: [95]  [80/97]  eta: 0:00:15  lr: 0.000028  loss: 4.2850 (4.3233)  time: 0.7983  data: 0.0009  max mem: 46135
# Epoch: [95]  [90/97]  eta: 0:00:06  lr: 0.000028  loss: 4.2749 (4.3136)  time: 0.7962  data: 0.0007  max mem: 46135
# Epoch: [95]  [96/97]  eta: 0:00:00  lr: 0.000028  loss: 4.3232 (4.3097)  time: 0.7951  data: 0.0006  max mem: 46135
# Epoch: [95] Total time: 0:01:25 (0.8809 s / it)
# Averaged stats: lr: 0.000028  loss: 4.3232 (4.3097)
# Test:  [0/7]  eta: 0:00:45  loss: 4.3757 (4.3757)  acc1: 24.1536 (24.1536)  acc5: 51.8229 (51.8229)  time: 6.5198  data: 6.3014  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3757 (4.3644)  acc1: 26.0417 (27.6800)  acc5: 51.8229 (54.6000)  time: 1.0931  data: 0.9004  max mem: 46135
# Test: Total time: 0:00:07 (1.1038 s / it)
# * Acc@1 27.680 Acc@5 54.600 loss 4.364
# Accuracy of the network on the 10000 test images: 27.7%
# Max accuracy: 27.68%
# Epoch: [96]  [ 0/97]  eta: 0:12:16  lr: 0.000022  loss: 3.9821 (3.9821)  time: 7.5971  data: 6.7810  max mem: 46135
# Epoch: [96]  [10/97]  eta: 0:02:03  lr: 0.000022  loss: 4.4386 (4.3027)  time: 1.4206  data: 0.6169  max mem: 46135
# Epoch: [96]  [20/97]  eta: 0:01:26  lr: 0.000022  loss: 4.2754 (4.2236)  time: 0.8034  data: 0.0006  max mem: 46135
# Epoch: [96]  [30/97]  eta: 0:01:08  lr: 0.000022  loss: 4.2565 (4.2452)  time: 0.8023  data: 0.0006  max mem: 46135
# Epoch: [96]  [40/97]  eta: 0:00:55  lr: 0.000022  loss: 4.3615 (4.2610)  time: 0.8009  data: 0.0006  max mem: 46135
# Epoch: [96]  [50/97]  eta: 0:00:43  lr: 0.000022  loss: 4.3667 (4.2776)  time: 0.7996  data: 0.0006  max mem: 46135
# Epoch: [96]  [60/97]  eta: 0:00:33  lr: 0.000022  loss: 4.4160 (4.2891)  time: 0.8000  data: 0.0006  max mem: 46135
# Epoch: [96]  [70/97]  eta: 0:00:24  lr: 0.000022  loss: 4.4363 (4.3052)  time: 0.7985  data: 0.0006  max mem: 46135
# Epoch: [96]  [80/97]  eta: 0:00:15  lr: 0.000022  loss: 4.4735 (4.3084)  time: 0.7971  data: 0.0010  max mem: 46135
# Epoch: [96]  [90/97]  eta: 0:00:06  lr: 0.000022  loss: 4.4735 (4.3116)  time: 0.7966  data: 0.0008  max mem: 46135
# Epoch: [96]  [96/97]  eta: 0:00:00  lr: 0.000022  loss: 4.5048 (4.3128)  time: 0.7949  data: 0.0007  max mem: 46135
# Epoch: [96] Total time: 0:01:24 (0.8722 s / it)
# Averaged stats: lr: 0.000022  loss: 4.5048 (4.3128)
# Test:  [0/7]  eta: 0:00:44  loss: 4.3635 (4.3635)  acc1: 23.7630 (23.7630)  acc5: 51.8880 (51.8880)  time: 6.2932  data: 6.0815  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3635 (4.3602)  acc1: 25.7812 (27.3300)  acc5: 51.8880 (54.4800)  time: 1.0607  data: 0.8690  max mem: 46135
# Test: Total time: 0:00:07 (1.0713 s / it)
# * Acc@1 27.330 Acc@5 54.480 loss 4.360
# Accuracy of the network on the 10000 test images: 27.3%
# Max accuracy: 27.68%
# Epoch: [97]  [ 0/97]  eta: 0:14:00  lr: 0.000018  loss: 4.4100 (4.4100)  time: 8.6622  data: 7.8435  max mem: 46135
# Epoch: [97]  [10/97]  eta: 0:02:12  lr: 0.000018  loss: 4.5160 (4.4188)  time: 1.5188  data: 0.7141  max mem: 46135
# Epoch: [97]  [20/97]  eta: 0:01:30  lr: 0.000018  loss: 4.5160 (4.4241)  time: 0.8024  data: 0.0009  max mem: 46135
# Epoch: [97]  [30/97]  eta: 0:01:10  lr: 0.000018  loss: 4.4031 (4.3967)  time: 0.8004  data: 0.0006  max mem: 46135
# Epoch: [97]  [40/97]  eta: 0:00:56  lr: 0.000018  loss: 4.4079 (4.3926)  time: 0.7998  data: 0.0006  max mem: 46135
# Epoch: [97]  [50/97]  eta: 0:00:44  lr: 0.000018  loss: 4.3069 (4.3548)  time: 0.7987  data: 0.0005  max mem: 46135
# Epoch: [97]  [60/97]  eta: 0:00:34  lr: 0.000018  loss: 4.3151 (4.3624)  time: 0.7984  data: 0.0005  max mem: 46135
# Epoch: [97]  [70/97]  eta: 0:00:24  lr: 0.000018  loss: 4.4475 (4.3649)  time: 0.7987  data: 0.0006  max mem: 46135
# Epoch: [97]  [80/97]  eta: 0:00:15  lr: 0.000018  loss: 4.5238 (4.3758)  time: 0.7993  data: 0.0010  max mem: 46135
# Epoch: [97]  [90/97]  eta: 0:00:06  lr: 0.000018  loss: 4.4247 (4.3664)  time: 0.7973  data: 0.0007  max mem: 46135
# Epoch: [97]  [96/97]  eta: 0:00:00  lr: 0.000018  loss: 4.1226 (4.3378)  time: 0.7961  data: 0.0006  max mem: 46135
# Epoch: [97] Total time: 0:01:25 (0.8830 s / it)
# Averaged stats: lr: 0.000018  loss: 4.1226 (4.3378)
# Test:  [0/7]  eta: 0:00:43  loss: 4.3672 (4.3672)  acc1: 23.9583 (23.9583)  acc5: 51.6927 (51.6927)  time: 6.2524  data: 6.0369  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3672 (4.3642)  acc1: 25.4557 (27.2800)  acc5: 51.6927 (54.6100)  time: 1.1290  data: 0.9367  max mem: 46135
# Test: Total time: 0:00:07 (1.1411 s / it)
# * Acc@1 27.280 Acc@5 54.610 loss 4.364
# Accuracy of the network on the 10000 test images: 27.3%
# Max accuracy: 27.68%
# Epoch: [98]  [ 0/97]  eta: 0:15:34  lr: 0.000014  loss: 3.9188 (3.9188)  time: 9.6292  data: 8.8038  max mem: 46135
# Epoch: [98]  [10/97]  eta: 0:02:20  lr: 0.000014  loss: 4.0864 (4.1136)  time: 1.6092  data: 0.8012  max mem: 46135
# Epoch: [98]  [20/97]  eta: 0:01:34  lr: 0.000014  loss: 4.2950 (4.2384)  time: 0.8038  data: 0.0007  max mem: 46135
# Epoch: [98]  [30/97]  eta: 0:01:12  lr: 0.000014  loss: 4.5052 (4.3124)  time: 0.8000  data: 0.0006  max mem: 46135
# Epoch: [98]  [40/97]  eta: 0:00:57  lr: 0.000014  loss: 4.3509 (4.2958)  time: 0.7995  data: 0.0006  max mem: 46135
# Epoch: [98]  [50/97]  eta: 0:00:45  lr: 0.000014  loss: 4.2560 (4.2948)  time: 0.7984  data: 0.0006  max mem: 46135
# Epoch: [98]  [60/97]  eta: 0:00:34  lr: 0.000014  loss: 4.4256 (4.3038)  time: 0.7974  data: 0.0005  max mem: 46135
# Epoch: [98]  [70/97]  eta: 0:00:24  lr: 0.000014  loss: 4.2652 (4.2955)  time: 0.7967  data: 0.0005  max mem: 46135
# Epoch: [98]  [80/97]  eta: 0:00:15  lr: 0.000014  loss: 4.4038 (4.2965)  time: 0.7961  data: 0.0009  max mem: 46135
# Epoch: [98]  [90/97]  eta: 0:00:06  lr: 0.000014  loss: 4.3296 (4.2769)  time: 0.7956  data: 0.0007  max mem: 46135
# Epoch: [98]  [96/97]  eta: 0:00:00  lr: 0.000014  loss: 4.2569 (4.2740)  time: 0.7956  data: 0.0006  max mem: 46135
# Epoch: [98] Total time: 0:01:26 (0.8919 s / it)
# Averaged stats: lr: 0.000014  loss: 4.2569 (4.2740)
# Test:  [0/7]  eta: 0:00:46  loss: 4.3670 (4.3670)  acc1: 24.3490 (24.3490)  acc5: 52.1484 (52.1484)  time: 6.6988  data: 6.4822  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3670 (4.3640)  acc1: 26.1068 (27.7800)  acc5: 52.1484 (54.9700)  time: 1.1186  data: 0.9262  max mem: 46135
# Test: Total time: 0:00:07 (1.1359 s / it)
# * Acc@1 27.780 Acc@5 54.970 loss 4.364
# Accuracy of the network on the 10000 test images: 27.8%
# Max accuracy: 27.78%
# Epoch: [99]  [ 0/97]  eta: 0:16:47  lr: 0.000012  loss: 4.6757 (4.6757)  time: 10.3827  data: 9.5675  max mem: 46135
# Epoch: [99]  [10/97]  eta: 0:02:25  lr: 0.000012  loss: 4.5258 (4.3741)  time: 1.6690  data: 0.8703  max mem: 46135
# Epoch: [99]  [20/97]  eta: 0:01:36  lr: 0.000012  loss: 4.3599 (4.3232)  time: 0.7982  data: 0.0007  max mem: 46135
# Epoch: [99]  [30/97]  eta: 0:01:14  lr: 0.000012  loss: 4.3599 (4.3369)  time: 0.7984  data: 0.0007  max mem: 46135
# Epoch: [99]  [40/97]  eta: 0:00:58  lr: 0.000012  loss: 4.1673 (4.2698)  time: 0.7996  data: 0.0006  max mem: 46135
# Epoch: [99]  [50/97]  eta: 0:00:46  lr: 0.000012  loss: 4.2204 (4.2995)  time: 0.7997  data: 0.0006  max mem: 46135
# Epoch: [99]  [60/97]  eta: 0:00:35  lr: 0.000012  loss: 4.3914 (4.3014)  time: 0.7971  data: 0.0005  max mem: 46135
# Epoch: [99]  [70/97]  eta: 0:00:25  lr: 0.000012  loss: 4.4495 (4.3303)  time: 0.7989  data: 0.0005  max mem: 46135
# Epoch: [99]  [80/97]  eta: 0:00:15  lr: 0.000012  loss: 4.5289 (4.3458)  time: 0.7991  data: 0.0009  max mem: 46135
# Epoch: [99]  [90/97]  eta: 0:00:06  lr: 0.000012  loss: 4.4454 (4.3441)  time: 0.7957  data: 0.0007  max mem: 46135
# Epoch: [99]  [96/97]  eta: 0:00:00  lr: 0.000012  loss: 4.4533 (4.3521)  time: 0.7954  data: 0.0005  max mem: 46135
# Epoch: [99] Total time: 0:01:27 (0.8995 s / it)
# Averaged stats: lr: 0.000012  loss: 4.4533 (4.3521)
# Test:  [0/7]  eta: 0:00:41  loss: 4.3718 (4.3718)  acc1: 24.0234 (24.0234)  acc5: 51.3672 (51.3672)  time: 5.9134  data: 5.6896  max mem: 46135
# Test:  [6/7]  eta: 0:00:01  loss: 4.3718 (4.3646)  acc1: 25.3906 (27.1400)  acc5: 51.6276 (54.2600)  time: 1.0671  data: 0.8737  max mem: 46135
# Test: Total time: 0:00:07 (1.0837 s / it)
# * Acc@1 27.140 Acc@5 54.260 loss 4.365
# Accuracy of the network on the 10000 test images: 27.1%
# Max accuracy: 27.78%
# Training time 2:38:00

# %% [markdown]
# # **Layer 2: Base Environment — Teacher Models & Multi-Teacher Adaptations**

# %% [markdown]
# Layer 2 extends the baseline DeiT environment to support knowledge distillation from one or more teacher models. This layer is additive: it does not modify the baseline DeiT training loop unless explicitly stated.
# It includes
# 1. Teacher Model Support (Single & Multiple)
# 2. Teacher Registry / Configuration
# 3. Multi-Teacher Fusion Mechanism (Adaptation Layer)
# 4. Distillation Loss Integration
